# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pandas import Series
from pandas import read_csv

# %%
# !pip install rdflib 
import rdflib
# !pip install SPARQLWrapper
from SPARQLWrapper import SPARQLWrapper, JSON
import ssl

# %%
! pip install https://github.com/pandas-profiling/pandas-profiling/archive/master.zip 
import pandas_profiling as pp

# %%
# !pip install pandas-profiling==3.2.0

# %%
led_endpoint="http://data.open.ac.uk/sparql"

sparql_wd = SPARQLWrapper(led_endpoint)

# %% [markdown]
# # QUERIES  pre - war period
#
#
#
# * CQ1: What music was being played?
# * CQ2: Who was listening to the music?
# * CQ3: How did the instruments used change over time?
# * CQ5: Where were the musicians coming from?
# * CQ7: Where were the places (in which they played?)
# * CQ10: How does the world of brass bands connect with that of elite music?
# * CQ11: What did people ‘make of’, how did they react to, e.g. music?
# * CQ12: Who was the author of a piece of music? e.g. can we identify it by its incipit?
#
# * CQ14: What is the cause of a change, e.g. increasing number of concerts over time? # cannot be answered with a simple query, we have to identify the change
# <br>
#
# * CQ13: What was the country of origin of a piece of music? - we still have not retrieved info about this one. would it be interesting?

# %% [markdown]
# ##CQ1: What music was being played?

# %%
query_prewar= """PREFIX dc: <http://purl.org/dc/terms/>
PREFIX edtf: <http://data.open.ac.uk/edtf/ontology/>
PREFIX edtfdata: <http://data.open.ac.uk/time/edtf/>
PREFIX event: <http://purl.org/NET/c4dm/event.owl#>
PREFIX led: <http://led.kmi.open.ac.uk/term/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX schema: <http://schema.org/>
prefix mo:<http://purl.org/ontology/mo/>
SELECT DISTINCT  ?lexp ?perf ?perflabel ?label ?songlabel ?genrelabel ?yoc
WHERE {
   # ?lexp event:time [ rdfs:label ?when ; edtf:century edtfdata:Century.19 ; edtf:yearOfCentury/rdf:value ?yoc ].
   # ?lexp  dc:subject ?perf.
   # ?perf mo:performance_of ?song.
   # ?perf rdfs:label ?perflabel.
   # ?song rdfs:label ?songlabel.
   # ?perf mo:genre ?genre.
   # ?genre rdfs:label ?genrelabel.
   FILTER ( ?yoc >= 32 && ?yoc <= 38 ) 
}"""
# set the query
sparql_wd.setQuery(query_prewar)
# set the returned format
sparql_wd.setReturnFormat(JSON)
# get the results
results = sparql_wd.query().convert()

results

# %%
#import pandas as pds

#df = pds.DataFrame(results['results']['bindings'])

#df.applymap(lambda x: x['value'])

# %%
df = pd.DataFrame(columns=['lexp','perf','perflabel','songlabel','genrelabel', 'yoc'])
idx=0
for result in results["results"]["bindings"]:
    df.loc[idx] = [result["lexp"]["value"],result["perf"]["value"],result["perflabel"]["value"],result["songlabel"]["value"],result['genrelabel']['value'],result['yoc']['value']]
    idx+=1

# %%
music = df.drop_duplicates()
music
# Out:
#                                               lexp  \
# 0    http://data.open.ac.uk/led/lexp/1434481073543
# 1    http://data.open.ac.uk/led/lexp/1448985100239
# 3    http://data.open.ac.uk/led/lexp/1426871249587
# 4    http://data.open.ac.uk/led/lexp/1426871266847
# 5    http://data.open.ac.uk/led/lexp/1426871266847
# ..                                             ...
# 418  http://data.open.ac.uk/led/lexp/1446380822350
# 419  http://data.open.ac.uk/led/lexp/1446402813424
# 422  http://data.open.ac.uk/led/lexp/1446380822350
# 423  http://data.open.ac.uk/led/lexp/1446402813424
# 424  http://data.open.ac.uk/led/lexp/1437660200124
#
#                                                   perf  \
# 0    http://data.open.ac.uk/led/performance/http://...
# 1    http://data.open.ac.uk/led/performance/6c8c036...
# 3    http://data.open.ac.uk/led/performance/http://...
# 4    http://data.open.ac.uk/led/performance/http://...
# 5    http://data.open.ac.uk/led/performance/http://...
# ..                                                 ...
# 418  http://data.open.ac.uk/led/performance/7715032...
# 419  http://data.open.ac.uk/led/performance/45b7918...
# 422  http://data.open.ac.uk/led/performance/7715032...
# 423  http://data.open.ac.uk/led/performance/45b7918...
# 424  http://data.open.ac.uk/led/performance/449cf75...
#
#                                              perflabel  \
# 0           performance of 'Phantasy in F sharp minor'
# 1    performance of 'Chamber music works by Schoenb...
# 3         performance of ''Our Hunting Fathers' op. 8'
# 4              performance of ''Five Tudor Portraits''
# 5              performance of ''Five Tudor Portraits''
# ..                                                 ...
# 418                           performance of 'Macbeth'
# 419                      performance of 'The Wreckers'
# 422                           performance of 'Macbeth'
# 423                      performance of 'The Wreckers'
# 424                      performance of 'Go Play, Boy'
#
#                                             songlabel       genrelabel yoc
# 0                           Phantasy in F sharp minor    Piano quartet  32
# 1    Chamber music works by Schoenberg and his school    Chamber music  37
# 3                         'Our Hunting Fathers' op. 8  Classical music  36
# 4                              'Five Tudor Portraits'  Classical music  36
# 5                                Five Tudor Portraits  Classical music  36
# ..                                                ...              ...  ..
# 418                                           Macbeth            Opera  34
# 419                                      The Wreckers            Opera  35
# 422                                           Macbeth         Operatic  34
# 423                                      The Wreckers         Operatic  35
# 424                                      Go Play, Boy   String quartet  33
#
# [273 rows x 6 columns]

# %%
import pandas_profiling as pp

pp.ProfileReport(music)

# %% [markdown]
# ##Frequency of songs being played

# %%
freq_song = """PREFIX dc: <http://purl.org/dc/terms/>
PREFIX edtf: <http://data.open.ac.uk/edtf/ontology/>
PREFIX edtfdata: <http://data.open.ac.uk/time/edtf/>
PREFIX event: <http://purl.org/NET/c4dm/event.owl#>
PREFIX led: <http://led.kmi.open.ac.uk/term/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX schema: <http://schema.org/>
prefix mo:<http://purl.org/ontology/mo/>

SELECT ?song ?songlabel ?musicfrequency WHERE {
SELECT DISTINCT ?song (COUNT(?song) as ?musicfrequency)
WHERE {
   # ?lexp event:time [ rdfs:label ?when ; edtf:century edtfdata:Century.19 ; edtf:yearOfCentury/rdf:value ?yoc ].
   # ?lexp  dc:subject ?perf.
   # ?perf mo:performance_of ?song.
   # ?perf rdfs:label ?perflabel.
   # ?song rdfs:label ?songlabel.
   # ?perf mo:genre ?genre.
   # ?genre rdfs:label ?genrelabel.
   FILTER ( ?yoc >= 32 && ?yoc <= 38 ) 
}
GROUP BY ?song
}
ORDER BY DESC(?musicfrequency)"""

# set the query
sparql_wd.setQuery(freq_song)
# set the returned format
sparql_wd.setReturnFormat(JSON)
# get the results
results = sparql_wd.query().convert()

results
# Out:
# {'head': {'vars': ['song', 'songlabel', 'musicfrequency']},
#  'results': {'bindings': [{'song': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music/Der+Eing+des+Nibelungen/1439033179904'},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '24'}},
#    {'song': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music/Hansel+und+Gretel/1438108572879'},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '15'}},
#    {'song': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music/Beethoven+9/1447172558154'},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '14'}},
#    {'song': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music/Requiem/1388427609504'},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '12'}},
#    {'song': {'type': 'uri',
#      'value': "http://data.open.ac.uk/led/music/'Die+Meistersinger+von+N%C3%BCrnberg'/1429015427310"},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '12'}},
#    {'song': {'type': 'uri',
#      'value': "http://data.open.ac.uk/led/music/'Die+Zauberfl%C3%B6te'+K620/1423077156061"},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '12'}},
#    {'song': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music/Sonata+for+two+pianos+and+percussion/1450116247842'},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '12'}},
#    {'song': {'type': 'uri',
#      'value': "http://data.open.ac.uk/led/music/'Stormy+Weather'/1429377484433"},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '10'}},
#    {'song': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music/Fifth+Symphony/1388487985867'},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '9'}},
#    {'song': {'type': 'uri',
#      'value': "http://data.open.ac.uk/led/music/Beethoven's+Third+and+Fifth+symphonies/1431351646627"},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '8'}},
#    {'song': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music/%E2%80%98Pers%C3%A9phone%E2%80%99/1435675710640'},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '8'}},
#    {'song': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music/Masses+and+Mozart+operas+in+Salzburg/1409766031751'},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '7'}},
#    {'song': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music/Idyll+from+Siegried/1435697970586'},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '6'}},
#    {'song': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music/Mozart+Sonata+for+violin+and+piano/1409776183730'},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '6'}},
#    {'song': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music/Salome/1444653451933'},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '5'}},
#    {'song': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music/Siegfried/1438198269493'},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '5'}},
#    {'song': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music/Nozze+di+Figaro/1431604271341'},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '5'}},
#    {'song': {'type': 'uri',
#      'value': "http://data.open.ac.uk/led/music/'A+Village+Romeo+and+Juliet'/1426344222684"},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '5'}},
#    {'song': {'type': 'uri',
#      'value': "http://data.open.ac.uk/led/music/'Louise'/1429016237479"},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '5'}},
#    {'song': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music/Ave+Maria/1436193392486'},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '4'}},
#    {'song': {'type': 'uri',
#      'value': "http://data.open.ac.uk/led/music/'Falstaff'+-+symphonic+study+in+C+minor+op.+68/1419693768238"},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '4'}},
#    {'song': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music/String+Quartets+op.18/1393950736208'},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '4'}},
#    {'song': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music/Five+Tudor+Portraits/1444319133927'},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '4'}},
#    {'song': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music/Katerina+Izmailova/1451587180875'},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '4'}},
#    {'song': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music/Lady+Macbeth+of+Mtsensk/1451586294150'},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '4'}},
#    {'song': {'type': 'uri',
#      'value': "http://data.open.ac.uk/led/music/
},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'}},
#    {'song': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music/processional+music+for+a+Spanish+patronal+festival/1404493092587'},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'}},
#    {'song': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music/pasodoble/1404405074691'},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'}},
#    {'song': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music/pasodobles/1404495337993'},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'}},
#    {'song': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music/waltzes/1404495379563'},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'}},
#    {'song': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music/Chamber+music+works+by+Schoenberg+and+his+school/1448985066936'},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'}},
#    {'song': {'type': 'uri',
#      'value': "http://data.open.ac.uk/led/music/'Our+Hunting+Fathers'+op.+8/1427032502919"},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'}},
#    {'song': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music/Viola+Concerto/1422901793319'},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'}},
#    {'song': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music/Magnificat+in+D,+BWV+243/1427034684538'},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'}},
#    {'song': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music/Capriccio/1435675974164'},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'}},
#    {'song': {'type': 'uri',
#      'value': "http://data.open.ac.uk/led/music/Feu+d'Artifice/1435675856950"},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'}},
#    {'song': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music/The+Firebird/1434117426629'},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'}},
#    {'song': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music/Non+sa+che+sia+dolore+(BWV+208)/1434662745051'},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'}},
#    {'song': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music/Go+Play,+Boy/1437660169215'},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'}},
#    {'song': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music/Violin+Concerto+in+D/1393950118964'},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'}},
#    {'song': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/performance/Notturno+for+four+orchestras+K.286+(,+performance+of)/1393950044675'},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'}},
#    {'song': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music/Symphony/1393950176369'},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'}},
#    {'song': {'type': 'uri',
#      'value': "http://data.open.ac.uk/led/music/Children's+choruses/1450115890823"},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'}},
#    {'song': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music/Mikrokosmos/1450115777819'},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'}},
#    {'song': {'type': 'uri',
#      'value': "http://data.open.ac.uk/led/music/Vaughan+Williams+-+'Pastoral+Symphony'+(conducted+by+the+composer)/1406889872805"},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '1'}},
#    {'song': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music/Pomona/1446306081223'},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '1'}},
#    {'song': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music/Phantasy+in+F+sharp+minor/1434481071370'},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '1'}},
#    {'song': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music/Le+Foyer+de+Danse/1434919082358'},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '1'}},
#    {'song': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music/Mr+Cinders/1434664891355'},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '1'}},
#    {'song': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music/Wedding+March/1446305105228'},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '1'}},
#    {'song': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music/Chu+Chin+Chow/1435695480400'},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '1'}},
#    {'song': {'type': 'uri',
#      'value': "http://data.open.ac.uk/led/music/'Lorna+Doone'/1426873561239"},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '1'}},
#    {'song': {'type': 'uri',
#      'value': "http://data.open.ac.uk/led/music/Ecco+mormorar+l'onde/1444743524730"},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '1'}},
#    {'song': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music/Amor/1444743480514'},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '1'}},
#    {'song': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music/Werther/1393949079238'},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '1'}},
#    {'song': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music/Firebird+Suite/1473084872051'},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '1'}},
#    {'song': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music/Two-part+Invention+in+C+major,+BWV772/1476998057110'},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '1'}},
#    {'song': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music/Polish+Dance/1451586023250'},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '1'}},
#    {'song': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music/Requiem/1438183778251'},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '1'}},
#    {'song': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music/Gretry+Pas+de+Deux/1434900375093'},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '1'}},
#    {'song': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music/Les+Sylphides/1434900436573'},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '1'}},
#    {'song': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music/Manhattan+Serenade/1434900221339'},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '1'}},
#    {'song': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music/Yeoman+of+the+Guard/1399392756633'},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '1'}},
#    {'song': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music/Falstaff,+Op+68/1435095735587'},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '1'}},
#    {'song': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music/Gallimaufry/1414591647990'},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '1'}},
#    {'song': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music/Maria+im+Walde/1414591720308'},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '1'}},
#    {'song': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music/Stewelpeter/1414592170628'},
#     'musicfrequency': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '1'}}]}}

# %% [markdown]
# ##CQ2: Who was listening to the music?

# %%
listener = """PREFIX dc: <http://purl.org/dc/terms/>
PREFIX edtf: <http://data.open.ac.uk/edtf/ontology/>
PREFIX edtfdata: <http://data.open.ac.uk/time/edtf/>
PREFIX event: <http://purl.org/NET/c4dm/event.owl#>
PREFIX led: <http://led.kmi.open.ac.uk/term/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX schema: <http://schema.org/>
prefix mo:<http://purl.org/ontology/mo/>
prefix db:<http://dbpedia.org/ontology/>
prefix uk:<http://data.open.ac.uk/ukresearchproject/ontology/>
prefix ox:<http://vocab.ox.ac.uk/projectfunding#>
PREFIX geo: <http://www.w3.org/2003/01/geo/wgs84_pos#>

SELECT DISTINCT ?listener ?givenName ?familyName ?birthdate ?nat ?occupation ?yoc

WHERE {
   # ?lexp event:time [ rdfs:label ?when ; edtf:century edtfdata:Century.19 ; edtf:yearOfCentury/rdf:value ?yoc ].
   # ?lexp dc:subject ?perf.
   # ?perf mo:listener ?listener.
   # ?listener foaf:givenName ?givenName ;
             foaf:familyName ?familyName ;
             schema:birthDate ?birthdate ;
             schema:nationality ?nat .
   # ?listener db:occupation ?occupation .
   FILTER ( ?yoc >= 32 && ?yoc <= 38 ) 
}"""

# set the query
sparql_wd.setQuery(listener)
# set the returned format
sparql_wd.setReturnFormat(JSON)
# get the results
results = sparql_wd.query().convert()

results
# Out:
# {'head': {'vars': ['lexp',
#    'listener',
#    'givenName',
#    'familyName',
#    'birthdate',
#    'nat',
#    'occupation',
#    'yoc']},
#  'results': {'bindings': [{'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1426341004158'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/time/edtf/1909-uu-uu'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Writer'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '34'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1426341004158'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/time/edtf/1909-uu-uu'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/clarinettist+music+librarian,+writer'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '34'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1426341004158'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/time/edtf/1909-uu-uu'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music+librarian'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '34'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1426341004158'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/time/edtf/1909-uu-uu'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Clarinetist'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '34'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1426871318822'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/time/edtf/1909-uu-uu'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Writer'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '36'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1426871318822'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/time/edtf/1909-uu-uu'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/clarinettist+music+librarian,+writer'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '36'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1426871318822'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/time/edtf/1909-uu-uu'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music+librarian'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '36'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1426871318822'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/time/edtf/1909-uu-uu'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Clarinetist'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '36'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1426871003793'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/time/edtf/1909-uu-uu'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Writer'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '35'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1426871003793'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/time/edtf/1909-uu-uu'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/clarinettist+music+librarian,+writer'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '35'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1426871003793'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/time/edtf/1909-uu-uu'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music+librarian'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '35'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1426871003793'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/time/edtf/1909-uu-uu'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Clarinetist'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '35'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1426871298804'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/time/edtf/1909-uu-uu'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Writer'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '36'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1426871298804'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/time/edtf/1909-uu-uu'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/clarinettist+music+librarian,+writer'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '36'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1426871298804'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/time/edtf/1909-uu-uu'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music+librarian'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '36'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1426871298804'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/time/edtf/1909-uu-uu'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Clarinetist'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '36'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1424774032718'},
#     'listener': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/person/Randall+Thompson/1424773917870'},
#     'givenName': {'type': 'literal', 'value': 'Randall'},
#     'familyName': {'type': 'literal', 'value': 'Thompson'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://reference.data.gov.uk/id/day/1899-04-21'},
#     'nat': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/United_States'},
#     'occupation': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Composer'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '36'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1426430140113'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/time/edtf/1909-uu-uu'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Writer'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '34'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1426430140113'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/time/edtf/1909-uu-uu'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/clarinettist+music+librarian,+writer'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '34'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1426430140113'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/time/edtf/1909-uu-uu'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music+librarian'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '34'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1426430140113'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/time/edtf/1909-uu-uu'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Clarinetist'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '34'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1426870914860'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/time/edtf/1909-uu-uu'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Writer'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '34'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1426870914860'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/time/edtf/1909-uu-uu'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/clarinettist+music+librarian,+writer'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '34'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1426870914860'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/time/edtf/1909-uu-uu'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music+librarian'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '34'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1426870914860'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/time/edtf/1909-uu-uu'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Clarinetist'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '34'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1426871231562'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/time/edtf/1909-uu-uu'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Writer'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '36'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1426871231562'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/time/edtf/1909-uu-uu'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/clarinettist+music+librarian,+writer'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '36'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1426871231562'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/time/edtf/1909-uu-uu'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music+librarian'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '36'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1426871231562'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/time/edtf/1909-uu-uu'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Clarinetist'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '36'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1429093353055'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/time/edtf/1909-uu-uu'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Writer'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '37'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1429093353055'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/time/edtf/1909-uu-uu'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/clarinettist+music+librarian,+writer'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '37'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1429093353055'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/time/edtf/1909-uu-uu'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music+librarian'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '37'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1429093353055'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/time/edtf/1909-uu-uu'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Clarinetist'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '37'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1426871284433'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/time/edtf/1909-uu-uu'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Writer'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '36'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1426871284433'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/time/edtf/1909-uu-uu'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/clarinettist+music+librarian,+writer'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '36'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1426871284433'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/time/edtf/1909-uu-uu'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music+librarian'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '36'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1426871284433'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/time/edtf/1909-uu-uu'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Clarinetist'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '36'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1429012909798'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/time/edtf/1909-uu-uu'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Writer'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '36'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1429012909798'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/time/edtf/1909-uu-uu'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/clarinettist+music+librarian,+writer'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '36'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1429012909798'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/time/edtf/1909-uu-uu'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music+librarian'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '36'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1429012909798'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/time/edtf/1909-uu-uu'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Clarinetist'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '36'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1426871159448'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/time/edtf/1909-uu-uu'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Writer'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '35'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1426871159448'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/time/edtf/1909-uu-uu'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/clarinettist+music+librarian,+writer'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '35'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1426871159448'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/time/edtf/1909-uu-uu'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music+librarian'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '35'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1426871159448'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/time/edtf/1909-uu-uu'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Clarinetist'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '35'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1429093278204'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/time/edtf/1909-uu-uu'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Writer'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '37'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1429093278204'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/time/edtf/1909-uu-uu'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/clarinettist+music+librarian,+writer'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '37'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1429093278204'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/time/edtf/1909-uu-uu'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music+librarian'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '37'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1429093278204'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/time/edtf/1909-uu-uu'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Clarinetist'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '37'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1426430114425'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/time/edtf/1909-uu-uu'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Writer'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '34'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1426430114425'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/time/edtf/1909-uu-uu'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/clarinettist+music+librarian,+writer'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '34'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1426430114425'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/time/edtf/1909-uu-uu'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music+librarian'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '34'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1426430114425'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/time/edtf/1909-uu-uu'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Clarinetist'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '34'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1429012701557'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/time/edtf/1909-uu-uu'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Writer'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '36'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1429012701557'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/time/edtf/1909-uu-uu'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/clarinettist+music+librarian,+writer'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '36'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1429012701557'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/time/edtf/1909-uu-uu'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music+librarian'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '36'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1429012701557'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/time/edtf/1909-uu-uu'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Clarinetist'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '36'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1426871025544'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/time/edtf/1909-uu-uu'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Writer'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '35'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1426871025544'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/time/edtf/1909-uu-uu'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/clarinettist+music+librarian,+writer'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '35'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1426871025544'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/time/edtf/1909-uu-uu'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music+librarian'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '35'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1426871025544'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/time/edtf/1909-uu-uu'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Clarinetist'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '35'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1426871249587'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/time/edtf/1909-uu-uu'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Writer'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '36'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1426871249587'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/time/edtf/1909-uu-uu'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/clarinettist+music+librarian,+writer'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '36'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1426871249587'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/time/edtf/1909-uu-uu'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/music+librarian'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '36'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1426871249587'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/time/edtf/1909-uu-uu'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Clarinetist'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '36'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1429093245339'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/time/edtf/1909-uu-uu'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Writer'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '37'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1429093245339'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/time/edtf/1909-uu-uu'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/clarinettist+music+librarian,+writer'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '37'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1429093245339'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/SavageRichardTemple1909-1996'},
#     'givenName': {'type': 'literal', 'value': 'Richard Temple'},
#     'familyName': {'type': 'literal', 'value': 'Savage'},
#     'birthdate': {'type': 'uri',
# ...
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Writer'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '32'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1404492379436'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/LeeLaurie'},
#     'givenName': {'type': 'literal', 'value': 'Laurie'},
#     'familyName': {'type': 'literal', 'value': 'Lee'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://reference.data.gov.uk/id/day/1914-06-26'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Writer'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '35'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1404405139236'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/LeeLaurie'},
#     'givenName': {'type': 'literal', 'value': 'Laurie'},
#     'familyName': {'type': 'literal', 'value': 'Lee'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://reference.data.gov.uk/id/day/1914-06-26'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Writer'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '35'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1404227370601'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/LeeLaurie'},
#     'givenName': {'type': 'literal', 'value': 'Laurie'},
#     'familyName': {'type': 'literal', 'value': 'Lee'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://reference.data.gov.uk/id/day/1914-06-26'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Writer'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '35'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1404493124604'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/LeeLaurie'},
#     'givenName': {'type': 'literal', 'value': 'Laurie'},
#     'familyName': {'type': 'literal', 'value': 'Lee'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://reference.data.gov.uk/id/day/1914-06-26'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Writer'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '35'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1404494925717'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/LeeLaurie'},
#     'givenName': {'type': 'literal', 'value': 'Laurie'},
#     'familyName': {'type': 'literal', 'value': 'Lee'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://reference.data.gov.uk/id/day/1914-06-26'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Writer'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '35'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1446306107881'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/WoolfVirginia1882-1941'},
#     'givenName': {'type': 'literal', 'value': 'Virginia'},
#     'familyName': {'type': 'literal', 'value': 'Woolf'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://reference.data.gov.uk/id/day/1882-01-25'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Writer'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '33'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1446401583511'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/WoolfVirginia1882-1941'},
#     'givenName': {'type': 'literal', 'value': 'Virginia'},
#     'familyName': {'type': 'literal', 'value': 'Woolf'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://reference.data.gov.uk/id/day/1882-01-25'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Writer'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '34'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1449058327586'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/WoolfVirginia1882-1941'},
#     'givenName': {'type': 'literal', 'value': 'Virginia'},
#     'familyName': {'type': 'literal', 'value': 'Woolf'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://reference.data.gov.uk/id/day/1882-01-25'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Writer'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '36'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1448919599008'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/WoolfVirginia1882-1941'},
#     'givenName': {'type': 'literal', 'value': 'Virginia'},
#     'familyName': {'type': 'literal', 'value': 'Woolf'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://reference.data.gov.uk/id/day/1882-01-25'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Writer'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '38'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1446305195796'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/WoolfVirginia1882-1941'},
#     'givenName': {'type': 'literal', 'value': 'Virginia'},
#     'familyName': {'type': 'literal', 'value': 'Woolf'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://reference.data.gov.uk/id/day/1882-01-25'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Writer'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '32'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1446380256324'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/WoolfVirginia1882-1941'},
#     'givenName': {'type': 'literal', 'value': 'Virginia'},
#     'familyName': {'type': 'literal', 'value': 'Woolf'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://reference.data.gov.uk/id/day/1882-01-25'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Writer'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '33'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1446754869247'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/WoolfVirginia1882-1941'},
#     'givenName': {'type': 'literal', 'value': 'Virginia'},
#     'familyName': {'type': 'literal', 'value': 'Woolf'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://reference.data.gov.uk/id/day/1882-01-25'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Writer'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '35'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1446403479145'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/WoolfVirginia1882-1941'},
#     'givenName': {'type': 'literal', 'value': 'Virginia'},
#     'familyName': {'type': 'literal', 'value': 'Woolf'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://reference.data.gov.uk/id/day/1882-01-25'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Writer'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '35'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1446754583543'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/WoolfVirginia1882-1941'},
#     'givenName': {'type': 'literal', 'value': 'Virginia'},
#     'familyName': {'type': 'literal', 'value': 'Woolf'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://reference.data.gov.uk/id/day/1882-01-25'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Writer'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '35'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1446379996849'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/WoolfVirginia1882-1941'},
#     'givenName': {'type': 'literal', 'value': 'Virginia'},
#     'familyName': {'type': 'literal', 'value': 'Woolf'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://reference.data.gov.uk/id/day/1882-01-25'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Writer'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '33'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1446401386042'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/WoolfVirginia1882-1941'},
#     'givenName': {'type': 'literal', 'value': 'Virginia'},
#     'familyName': {'type': 'literal', 'value': 'Woolf'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://reference.data.gov.uk/id/day/1882-01-25'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Writer'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '34'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1446402229537'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/WoolfVirginia1882-1941'},
#     'givenName': {'type': 'literal', 'value': 'Virginia'},
#     'familyName': {'type': 'literal', 'value': 'Woolf'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://reference.data.gov.uk/id/day/1882-01-25'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Writer'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '34'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1446380822350'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/WoolfVirginia1882-1941'},
#     'givenName': {'type': 'literal', 'value': 'Virginia'},
#     'familyName': {'type': 'literal', 'value': 'Woolf'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://reference.data.gov.uk/id/day/1882-01-25'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Writer'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '34'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1446304716352'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/WoolfVirginia1882-1941'},
#     'givenName': {'type': 'literal', 'value': 'Virginia'},
#     'familyName': {'type': 'literal', 'value': 'Woolf'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://reference.data.gov.uk/id/day/1882-01-25'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Writer'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '32'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1408110429181'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/PlowmanMax1883-1941'},
#     'givenName': {'type': 'literal', 'value': 'Max'},
#     'familyName': {'type': 'literal', 'value': 'Plowman'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://reference.data.gov.uk/id/day/1883-09-01'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Soldier'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '37'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1408110429181'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/PlowmanMax1883-1941'},
#     'givenName': {'type': 'literal', 'value': 'Max'},
#     'familyName': {'type': 'literal', 'value': 'Plowman'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://reference.data.gov.uk/id/day/1883-09-01'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Writer'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '37'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1408110429181'},
#     'listener': {'type': 'uri',
#      'value': 'http://bnb.data.bl.uk/id/person/PlowmanMax1883-1941'},
#     'givenName': {'type': 'literal', 'value': 'Max'},
#     'familyName': {'type': 'literal', 'value': 'Plowman'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://reference.data.gov.uk/id/day/1883-09-01'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/England'},
#     'occupation': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/thing/pacifist'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '37'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1483025941899'},
#     'listener': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/agent/Paul+Eluard/1483025757955'},
#     'givenName': {'type': 'literal', 'value': 'Paul'},
#     'familyName': {'type': 'literal', 'value': 'Eluard'},
#     'birthdate': {'type': 'uri',
#      'value': 'http://reference.data.gov.uk/id/day/1895-12-14'},
#     'nat': {'type': 'uri', 'value': 'http://dbpedia.org/resource/France'},
#     'occupation': {'type': 'uri', 'value': 'http://data.open.ac.uk/led/poet'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '38'}}]}}

# %% [markdown]
# ###What to do with people that appear meny times in the results? How to remove this sort of duplicates? E.G. Igor Fjodorowitsch that has multiple nationalities (Igor' Fëdorovič Stravinskij - typos??)
#
# !Retrieve correct names from wikipedia - owl:SameAs???

# %%
df = pd.DataFrame(columns=['lexp','listener','givenName','familyName','birthdate', 'nat', 'occupation', 'yoc'])
idx=0
for result in results["results"]["bindings"]:
    df.loc[idx] = [result["lexp"]["value"],result["listener"]["value"],result["givenName"]["value"],result["familyName"]["value"],result['birthdate']['value'],result['nat']['value'],result['occupation']['value'],result['yoc']['value']]
    idx+=1

# %%
df
# Out:
#                                               lexp  \
# 0    http://data.open.ac.uk/led/lexp/1426341004158
# 1    http://data.open.ac.uk/led/lexp/1426341004158
# 2    http://data.open.ac.uk/led/lexp/1426341004158
# 3    http://data.open.ac.uk/led/lexp/1426341004158
# 4    http://data.open.ac.uk/led/lexp/1426871318822
# ..                                             ...
# 263  http://data.open.ac.uk/led/lexp/1446304716352
# 264  http://data.open.ac.uk/led/lexp/1408110429181
# 265  http://data.open.ac.uk/led/lexp/1408110429181
# 266  http://data.open.ac.uk/led/lexp/1408110429181
# 267  http://data.open.ac.uk/led/lexp/1483025941899
#
#                                               listener       givenName  \
# 0    http://bnb.data.bl.uk/id/person/SavageRichardT...  Richard Temple
# 1    http://bnb.data.bl.uk/id/person/SavageRichardT...  Richard Temple
# 2    http://bnb.data.bl.uk/id/person/SavageRichardT...  Richard Temple
# 3    http://bnb.data.bl.uk/id/person/SavageRichardT...  Richard Temple
# 4    http://bnb.data.bl.uk/id/person/SavageRichardT...  Richard Temple
# ..                                                 ...             ...
# 263  http://bnb.data.bl.uk/id/person/WoolfVirginia1...        Virginia
# 264  http://bnb.data.bl.uk/id/person/PlowmanMax1883...             Max
# 265  http://bnb.data.bl.uk/id/person/PlowmanMax1883...             Max
# 266  http://bnb.data.bl.uk/id/person/PlowmanMax1883...             Max
# 267  http://data.open.ac.uk/led/agent/Paul+Eluard/1...            Paul
#
#     familyName                                       birthdate  \
# 0       Savage     http://data.open.ac.uk/time/edtf/1909-uu-uu
# 1       Savage     http://data.open.ac.uk/time/edtf/1909-uu-uu
# 2       Savage     http://data.open.ac.uk/time/edtf/1909-uu-uu
# 3       Savage     http://data.open.ac.uk/time/edtf/1909-uu-uu
# 4       Savage     http://data.open.ac.uk/time/edtf/1909-uu-uu
# ..         ...                                             ...
# 263      Woolf  http://reference.data.gov.uk/id/day/1882-01-25
# 264    Plowman  http://reference.data.gov.uk/id/day/1883-09-01
# 265    Plowman  http://reference.data.gov.uk/id/day/1883-09-01
# 266    Plowman  http://reference.data.gov.uk/id/day/1883-09-01
# 267     Eluard  http://reference.data.gov.uk/id/day/1895-12-14
#
#                                      nat  \
# 0    http://dbpedia.org/resource/England
# 1    http://dbpedia.org/resource/England
# 2    http://dbpedia.org/resource/England
# 3    http://dbpedia.org/resource/England
# 4    http://dbpedia.org/resource/England
# ..                                   ...
# 263  http://dbpedia.org/resource/England
# 264  http://dbpedia.org/resource/England
# 265  http://dbpedia.org/resource/England
# 266  http://dbpedia.org/resource/England
# 267   http://dbpedia.org/resource/France
#
#                                             occupation yoc
# 0                   http://dbpedia.org/resource/Writer  34
# 1    http://data.open.ac.uk/led/clarinettist+music+...  34
# 2           http://data.open.ac.uk/led/music+librarian  34
# 3              http://dbpedia.org/resource/Clarinetist  34
# 4                   http://dbpedia.org/resource/Writer  36
# ..                                                 ...  ..
# 263                 http://dbpedia.org/resource/Writer  32
# 264                http://dbpedia.org/resource/Soldier  37
# 265                 http://dbpedia.org/resource/Writer  37
# 266          http://data.open.ac.uk/led/thing/pacifist  37
# 267                    http://data.open.ac.uk/led/poet  38
#
# [268 rows x 8 columns]

# %% [markdown]
# ##CQ3: How did the instruments used change over time?

# %%
instruments = """PREFIX dc: <http://purl.org/dc/terms/>
PREFIX edtf: <http://data.open.ac.uk/edtf/ontology/>
PREFIX edtfdata: <http://data.open.ac.uk/time/edtf/>
PREFIX event: <http://purl.org/NET/c4dm/event.owl#>
PREFIX led: <http://led.kmi.open.ac.uk/term/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX schema: <http://schema.org/>
prefix mo:<http://purl.org/ontology/mo/>
SELECT DISTINCT   ?lexp ?perf ?perflabel ?instrument ?instrumentlabel ?genrelabel ?yoc
WHERE {
   # ?lexp event:time [ rdfs:label ?when ; edtf:century edtfdata:Century.19 ; edtf:yearOfCentury/rdf:value ?yoc ].
   # ?lexp  dc:subject ?perf.
   # ?perf rdfs:label ?perflabel.
   # ?perf mo:instrument ?instrument.
   # ?instrument rdfs:label ?instrumentlabel.
   # ?perf mo:genre ?genre.
   # ?genre rdfs:label ?genrelabel.
   FILTER ( ?yoc >= 32 && ?yoc <= 38 ) 
}"""

# set the query
sparql_wd.setQuery(instruments)
# set the returned format
sparql_wd.setReturnFormat(JSON)
# get the results
results = sparql_wd.query().convert()

results
# Out:
# {'head': {'vars': ['lexp',
#    'perf',
#    'perflabel',
#    'instrument',
#    'instrumentlabel',
#    'genrelabel',
#    'yoc']},
#  'results': {'bindings': [{'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1414586405220'},
#     'perf': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/performance/http://data.open.ac.uk/led/music/Suite+for+Chamber+Orchestra/1414586100698/1414586100712'},
#     'perflabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': "performance of 'Suite for Chamber Orchestra'"},
#     'instrument': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Orchestra'},
#     'instrumentlabel': {'type': 'literal', 'value': 'Orchestra'},
#     'genrelabel': {'type': 'literal', 'value': 'Chamber music'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '35'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1414586405220'},
#     'perf': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/performance/http://data.open.ac.uk/led/music/Suite+for+Chamber+Orchestra/1414586100698/1414586100712'},
#     'perflabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': "performance of 'Suite for Chamber Orchestra'"},
#     'instrument': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Orchestra'},
#     'instrumentlabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Orchestra'},
#     'genrelabel': {'type': 'literal', 'value': 'Chamber music'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '35'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1414586405220'},
#     'perf': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/performance/http://data.open.ac.uk/led/music/Suite+for+Chamber+Orchestra/1414586100698/1414586100712'},
#     'perflabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': "performance of 'Suite for Chamber Orchestra'"},
#     'instrument': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Orchestra'},
#     'instrumentlabel': {'type': 'literal', 'value': 'Orchestra'},
#     'genrelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Chamber music'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '35'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1414586405220'},
#     'perf': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/performance/http://data.open.ac.uk/led/music/Suite+for+Chamber+Orchestra/1414586100698/1414586100712'},
#     'perflabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': "performance of 'Suite for Chamber Orchestra'"},
#     'instrument': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Orchestra'},
#     'instrumentlabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Orchestra'},
#     'genrelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Chamber music'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '35'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1431351729781'},
#     'perf': {'type': 'uri',
#      'value': "http://data.open.ac.uk/led/performance/http://data.open.ac.uk/led/music/Shostakovich's+Fourth+Symphony/1427828957045/1431351699875"},
#     'perflabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': "performance of 'Shostakovich's Fourth Symphony'"},
#     'instrument': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Orchestra'},
#     'instrumentlabel': {'type': 'literal', 'value': 'Orchestra'},
#     'genrelabel': {'type': 'literal', 'value': 'Classical music'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '36'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1431351729781'},
#     'perf': {'type': 'uri',
#      'value': "http://data.open.ac.uk/led/performance/http://data.open.ac.uk/led/music/Shostakovich's+Fourth+Symphony/1427828957045/1431351699875"},
#     'perflabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': "performance of 'Shostakovich's Fourth Symphony'"},
#     'instrument': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Orchestra'},
#     'instrumentlabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Orchestra'},
#     'genrelabel': {'type': 'literal', 'value': 'Classical music'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '36'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1427124850894'},
#     'perf': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/performance/http://data.open.ac.uk/led/music/Classical/1427124763171/1427124763183'},
#     'perflabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': "performance of 'Classical'"},
#     'instrument': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Piano'},
#     'instrumentlabel': {'type': 'literal', 'value': 'Piano'},
#     'genrelabel': {'type': 'literal', 'value': 'Classical music'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '38'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1427124850894'},
#     'perf': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/performance/http://data.open.ac.uk/led/music/Classical/1427124763171/1427124763183'},
#     'perflabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': "performance of 'Classical'"},
#     'instrument': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Piano'},
#     'instrumentlabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Piano'},
#     'genrelabel': {'type': 'literal', 'value': 'Classical music'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '38'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1431351729781'},
#     'perf': {'type': 'uri',
#      'value': "http://data.open.ac.uk/led/performance/http://data.open.ac.uk/led/music/Shostakovich's+Fourth+Symphony/1427828957045/1431351699875"},
#     'perflabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': "performance of 'Shostakovich's Fourth Symphony'"},
#     'instrument': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Orchestra'},
#     'instrumentlabel': {'type': 'literal', 'value': 'Orchestra'},
#     'genrelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Classical music'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '36'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1431351729781'},
#     'perf': {'type': 'uri',
#      'value': "http://data.open.ac.uk/led/performance/http://data.open.ac.uk/led/music/Shostakovich's+Fourth+Symphony/1427828957045/1431351699875"},
#     'perflabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': "performance of 'Shostakovich's Fourth Symphony'"},
#     'instrument': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Orchestra'},
#     'instrumentlabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Orchestra'},
#     'genrelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Classical music'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '36'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1427124850894'},
#     'perf': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/performance/http://data.open.ac.uk/led/music/Classical/1427124763171/1427124763183'},
#     'perflabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': "performance of 'Classical'"},
#     'instrument': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Piano'},
#     'instrumentlabel': {'type': 'literal', 'value': 'Piano'},
#     'genrelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Classical music'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '38'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1427124850894'},
#     'perf': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/performance/http://data.open.ac.uk/led/music/Classical/1427124763171/1427124763183'},
#     'perflabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': "performance of 'Classical'"},
#     'instrument': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Piano'},
#     'instrumentlabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Piano'},
#     'genrelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Classical music'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '38'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1429377516982'},
#     'perf': {'type': 'uri',
#      'value': "http://data.open.ac.uk/led/performance/http://data.open.ac.uk/led/music/'Stormy+Weather'/1429377484433/1429377484444"},
#     'perflabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': "performance of ''Stormy Weather''"},
#     'instrument': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Female_vocals'},
#     'instrumentlabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Female vocals'},
#     'genrelabel': {'type': 'literal', 'value': 'Song'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '33'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1429377516982'},
#     'perf': {'type': 'uri',
#      'value': "http://data.open.ac.uk/led/performance/http://data.open.ac.uk/led/music/'Stormy+Weather'/1429377484433/1429377484444"},
#     'perflabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': "performance of ''Stormy Weather''"},
#     'instrument': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Female_vocals'},
#     'instrumentlabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Female vocals'},
#     'genrelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Song'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '33'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1404496858400'},
#     'perf': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/performance/On+with+the+motley+(,+performance+of)/1404496770502'},
#     'perflabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': "performance of 'On with the motley'"},
#     'instrument': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Violin'},
#     'instrumentlabel': {'type': 'literal', 'value': 'Violin'},
#     'genrelabel': {'type': 'literal', 'value': 'Opera'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '35'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1404496858400'},
#     'perf': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/performance/On+with+the+motley+(,+performance+of)/1404496770502'},
#     'perflabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': "performance of 'On with the motley'"},
#     'instrument': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Violin'},
#     'instrumentlabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Violin'},
#     'genrelabel': {'type': 'literal', 'value': 'Opera'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '35'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1404496858400'},
#     'perf': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/performance/On+with+the+motley+(,+performance+of)/1404496770502'},
#     'perflabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': "performance of 'On with the motley'"},
#     'instrument': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Violin'},
#     'instrumentlabel': {'type': 'literal', 'value': 'Violin'},
#     'genrelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Opera'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '35'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1404496858400'},
#     'perf': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/performance/On+with+the+motley+(,+performance+of)/1404496770502'},
#     'perflabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': "performance of 'On with the motley'"},
#     'instrument': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Violin'},
#     'instrumentlabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Violin'},
#     'genrelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Opera'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '35'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1404496858400'},
#     'perf': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/performance/On+with+the+motley+(,+performance+of)/1404496770502'},
#     'perflabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': "performance of 'On with the motley'"},
#     'instrument': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/
},
#     'perf': {'type': 'uri',
#      'value': "http://data.open.ac.uk/led/performance/http://data.open.ac.uk/led/music/'Der+Ring+des+Nibelungen'/1429014682493/1429014682505"},
#     'perflabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': "performance of ''Der Ring des Nibelungen''"},
#     'instrument': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Choir'},
#     'instrumentlabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Choir'},
#     'genrelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Solo'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '36'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1429012744114'},
#     'perf': {'type': 'uri',
#      'value': "http://data.open.ac.uk/led/performance/http://data.open.ac.uk/led/music/'Die+Meistersinger+von+N%25C3%25BCrnberg'/1429015427310/1429015427316"},
#     'perflabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': "performance of ''Die Meistersinger von N��rnberg''"},
#     'instrument': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Choir'},
#     'instrumentlabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Choir'},
#     'genrelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Solo'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '36'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1429012909798'},
#     'perf': {'type': 'uri',
# ...
#     'instrument': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Orchestra'},
#     'instrumentlabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Orchestra'},
#     'genrelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Operatic'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '32'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1477169656413'},
#     'perf': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/performance/48e8605a70449350417981b1d3bc10a1/1477169582833'},
#     'perflabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': "performance of 'Parsifal'"},
#     'instrument': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Violin'},
#     'instrumentlabel': {'type': 'literal', 'value': 'Violin'},
#     'genrelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Operatic'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '32'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1477169656413'},
#     'perf': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/performance/48e8605a70449350417981b1d3bc10a1/1477169582833'},
#     'perflabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': "performance of 'Parsifal'"},
#     'instrument': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Violin'},
#     'instrumentlabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Violin'},
#     'genrelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Operatic'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '32'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1477169656413'},
#     'perf': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/performance/48e8605a70449350417981b1d3bc10a1/1477169582833'},
#     'perflabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': "performance of 'Parsifal'"},
#     'instrument': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Female_vocals'},
#     'instrumentlabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Female vocals'},
#     'genrelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Operatic'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '32'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1477169656413'},
#     'perf': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/performance/48e8605a70449350417981b1d3bc10a1/1477169582833'},
#     'perflabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': "performance of 'Parsifal'"},
#     'instrument': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Male_vocals'},
#     'instrumentlabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Male vocals'},
#     'genrelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Operatic'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '32'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1477169656413'},
#     'perf': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/performance/48e8605a70449350417981b1d3bc10a1/1477169582833'},
#     'perflabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': "performance of 'Parsifal'"},
#     'instrument': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Baritone'},
#     'instrumentlabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Baritone'},
#     'genrelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Operatic'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '32'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1477169656413'},
#     'perf': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/performance/48e8605a70449350417981b1d3bc10a1/1477169582833'},
#     'perflabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': "performance of 'Parsifal'"},
#     'instrument': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Contralto'},
#     'instrumentlabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Contralto'},
#     'genrelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Operatic'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '32'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1393950796528'},
#     'perf': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/performance/String+Quartets+op.18+(,+performance+of)/1393950736225'},
#     'perflabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': "performance of 'String Quartets op.18'"},
#     'instrument': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/String_instrument'},
#     'instrumentlabel': {'type': 'literal', 'value': 'String instrument'},
#     'genrelabel': {'type': 'literal', 'value': 'Classical music'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '38'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1393950796528'},
#     'perf': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/performance/String+Quartets+op.18+(,+performance+of)/1393950736225'},
#     'perflabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': "performance of 'String Quartets op.18'"},
#     'instrument': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/String_instrument'},
#     'instrumentlabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'String instrument'},
#     'genrelabel': {'type': 'literal', 'value': 'Classical music'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '38'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1393950796528'},
#     'perf': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/performance/String+Quartets+op.18+(,+performance+of)/1393950736225'},
#     'perflabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': "performance of 'String Quartets op.18'"},
#     'instrument': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/String_instrument'},
#     'instrumentlabel': {'type': 'literal', 'value': 'String instrument'},
#     'genrelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Classical music'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '38'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1393950796528'},
#     'perf': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/performance/String+Quartets+op.18+(,+performance+of)/1393950736225'},
#     'perflabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': "performance of 'String Quartets op.18'"},
#     'instrument': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/String_instrument'},
#     'instrumentlabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'String instrument'},
#     'genrelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Classical music'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '38'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1393950796528'},
#     'perf': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/performance/String+Quartets+op.18+(,+performance+of)/1393950736225'},
#     'perflabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': "performance of 'String Quartets op.18'"},
#     'instrument': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/String_instrument'},
#     'instrumentlabel': {'type': 'literal', 'value': 'String instrument'},
#     'genrelabel': {'type': 'literal', 'value': 'String quartet'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '38'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1393950796528'},
#     'perf': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/performance/String+Quartets+op.18+(,+performance+of)/1393950736225'},
#     'perflabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': "performance of 'String Quartets op.18'"},
#     'instrument': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/String_instrument'},
#     'instrumentlabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'String instrument'},
#     'genrelabel': {'type': 'literal', 'value': 'String quartet'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '38'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1393950796528'},
#     'perf': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/performance/String+Quartets+op.18+(,+performance+of)/1393950736225'},
#     'perflabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': "performance of 'String Quartets op.18'"},
#     'instrument': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/String_instrument'},
#     'instrumentlabel': {'type': 'literal', 'value': 'String instrument'},
#     'genrelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'String quartet'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '38'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1393950796528'},
#     'perf': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/performance/String+Quartets+op.18+(,+performance+of)/1393950736225'},
#     'perflabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': "performance of 'String Quartets op.18'"},
#     'instrument': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/String_instrument'},
#     'instrumentlabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'String instrument'},
#     'genrelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'String quartet'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '38'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1450115937591'},
#     'perf': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/performance/a1d8effaed0a1a3cfa8f570a9b055fd5/1450115890837'},
#     'perflabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': "performance of 'Children's choruses'"},
#     'instrument': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Human_voice'},
#     'instrumentlabel': {'type': 'literal', 'value': 'Human voice'},
#     'genrelabel': {'type': 'literal', 'value': 'Classical music'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '37'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1450115937591'},
#     'perf': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/performance/a1d8effaed0a1a3cfa8f570a9b055fd5/1450115890837'},
#     'perflabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': "performance of 'Children's choruses'"},
#     'instrument': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Human_voice'},
#     'instrumentlabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Human voice'},
#     'genrelabel': {'type': 'literal', 'value': 'Classical music'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '37'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1450115937591'},
#     'perf': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/performance/44652993b327673b1a2ee52c3ed71265/1450115777833'},
#     'perflabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': "performance of 'Mikrokosmos'"},
#     'instrument': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Piano'},
#     'instrumentlabel': {'type': 'literal', 'value': 'Piano'},
#     'genrelabel': {'type': 'literal', 'value': 'Classical music'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '37'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1450115937591'},
#     'perf': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/performance/44652993b327673b1a2ee52c3ed71265/1450115777833'},
#     'perflabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': "performance of 'Mikrokosmos'"},
#     'instrument': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Piano'},
#     'instrumentlabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Piano'},
#     'genrelabel': {'type': 'literal', 'value': 'Classical music'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '37'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1450115937591'},
#     'perf': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/performance/a1d8effaed0a1a3cfa8f570a9b055fd5/1450115890837'},
#     'perflabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': "performance of 'Children's choruses'"},
#     'instrument': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Human_voice'},
#     'instrumentlabel': {'type': 'literal', 'value': 'Human voice'},
#     'genrelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Classical music'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '37'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1450115937591'},
#     'perf': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/performance/a1d8effaed0a1a3cfa8f570a9b055fd5/1450115890837'},
#     'perflabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': "performance of 'Children's choruses'"},
#     'instrument': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Human_voice'},
#     'instrumentlabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Human voice'},
#     'genrelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Classical music'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '37'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1450115937591'},
#     'perf': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/performance/44652993b327673b1a2ee52c3ed71265/1450115777833'},
#     'perflabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': "performance of 'Mikrokosmos'"},
#     'instrument': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Piano'},
#     'instrumentlabel': {'type': 'literal', 'value': 'Piano'},
#     'genrelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Classical music'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '37'}},
#    {'lexp': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/lexp/1450115937591'},
#     'perf': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/performance/44652993b327673b1a2ee52c3ed71265/1450115777833'},
#     'perflabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': "performance of 'Mikrokosmos'"},
#     'instrument': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Piano'},
#     'instrumentlabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Piano'},
#     'genrelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Classical music'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '37'}}]}}

# %%
import pandas as pds
df = pds.DataFrame(results['results']['bindings'])
df.applymap(lambda x: x['value'])
# Out:
#                                               lexp  \
# 0    http://data.open.ac.uk/led/lexp/1414586405220
# 1    http://data.open.ac.uk/led/lexp/1414586405220
# 2    http://data.open.ac.uk/led/lexp/1414586405220
# 3    http://data.open.ac.uk/led/lexp/1414586405220
# 4    http://data.open.ac.uk/led/lexp/1431351729781
# ..                                             ...
# 966  http://data.open.ac.uk/led/lexp/1450115937591
# 967  http://data.open.ac.uk/led/lexp/1450115937591
# 968  http://data.open.ac.uk/led/lexp/1450115937591
# 969  http://data.open.ac.uk/led/lexp/1450115937591
# 970  http://data.open.ac.uk/led/lexp/1450115937591
#
#                                                   perf  \
# 0    http://data.open.ac.uk/led/performance/http://...
# 1    http://data.open.ac.uk/led/performance/http://...
# 2    http://data.open.ac.uk/led/performance/http://...
# 3    http://data.open.ac.uk/led/performance/http://...
# 4    http://data.open.ac.uk/led/performance/http://...
# ..                                                 ...
# 966  http://data.open.ac.uk/led/performance/4465299...
# 967  http://data.open.ac.uk/led/performance/a1d8eff...
# 968  http://data.open.ac.uk/led/performance/a1d8eff...
# 969  http://data.open.ac.uk/led/performance/4465299...
# 970  http://data.open.ac.uk/led/performance/4465299...
#
#                                            perflabel  \
# 0       performance of 'Suite for Chamber Orchestra'
# 1       performance of 'Suite for Chamber Orchestra'
# 2       performance of 'Suite for Chamber Orchestra'
# 3       performance of 'Suite for Chamber Orchestra'
# 4    performance of 'Shostakovich's Fourth Symphony'
# ..                                               ...
# 966                     performance of 'Mikrokosmos'
# 967             performance of 'Children's choruses'
# 968             performance of 'Children's choruses'
# 969                     performance of 'Mikrokosmos'
# 970                     performance of 'Mikrokosmos'
#
#                                   instrument instrumentlabel       genrelabel  \
# 0      http://dbpedia.org/resource/Orchestra       Orchestra    Chamber music
# 1      http://dbpedia.org/resource/Orchestra       Orchestra    Chamber music
# 2      http://dbpedia.org/resource/Orchestra       Orchestra    Chamber music
# 3      http://dbpedia.org/resource/Orchestra       Orchestra    Chamber music
# 4      http://dbpedia.org/resource/Orchestra       Orchestra  Classical music
# ..                                       ...             ...              ...
# 966        http://dbpedia.org/resource/Piano           Piano  Classical music
# 967  http://dbpedia.org/resource/Human_voice     Human voice  Classical music
# 968  http://dbpedia.org/resource/Human_voice     Human voice  Classical music
# 969        http://dbpedia.org/resource/Piano           Piano  Classical music
# 970        http://dbpedia.org/resource/Piano           Piano  Classical music
#
#     yoc
# 0    35
# 1    35
# 2    35
# 3    35
# 4    36
# ..   ..
# 966  37
# 967  37
# 968  37
# 969  37
# 970  37
#
# [971 rows x 7 columns]

# %% [markdown]
# ##CQ5: Where were the musicians coming from?

# %%
musicians = """PREFIX dc: <http://purl.org/dc/terms/>
PREFIX edtf: <http://data.open.ac.uk/edtf/ontology/>
PREFIX edtfdata: <http://data.open.ac.uk/time/edtf/>
PREFIX event: <http://purl.org/NET/c4dm/event.owl#>
PREFIX led: <http://led.kmi.open.ac.uk/term/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX schema: <http://schema.org/>
prefix mo:<http://purl.org/ontology/mo/>
prefix db:<http://dbpedia.org/ontology/>
prefix uk:<http://data.open.ac.uk/ukresearchproject/ontology/>
prefix ox:<http://vocab.ox.ac.uk/projectfunding#>
  
SELECT DISTINCT  ?perf ?artist ?artistlabel ?natlabel ?yoc
WHERE { 
  # ?lexp event:time [ rdfs:label ?when ; edtf:century edtfdata:Century.19 ; edtf:yearOfCentury/rdf:value ?yoc ].
  # ?lexp dc:subject ?perf.
  # ?perf mo:performer ?artist.
  # ?artist rdfs:label ?artistlabel.
  # ?artist schema:nationality ?nat.
  # ?nat rdfs:label ?natlabel.
  FILTER ( ?yoc >= 32 && ?yoc <= 38 )
}"""

# set the query
sparql_wd.setQuery(musicians)
# set the returned format
sparql_wd.setReturnFormat(JSON)
# get the results
results = sparql_wd.query().convert()

results

# %% [markdown]
# ##CQ7: Where were the places (in which they played?)

# %%
place = """PREFIX dc: <http://purl.org/dc/terms/>
PREFIX edtf: <http://data.open.ac.uk/edtf/ontology/>
PREFIX edtfdata: <http://data.open.ac.uk/time/edtf/>
PREFIX event: <http://purl.org/NET/c4dm/event.owl#>
PREFIX led: <http://led.kmi.open.ac.uk/term/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX schema: <http://schema.org/>
prefix mo:<http://purl.org/ontology/mo/>
prefix db:<http://dbpedia.org/ontology/>
prefix uk:<http://data.open.ac.uk/ukresearchproject/ontology/>
prefix ox:<http://vocab.ox.ac.uk/projectfunding#>
PREFIX geo: <http://www.w3.org/2003/01/geo/wgs84_pos#>  
SELECT DISTINCT  ?perf ?place ?placelabel ?lat ?long ?yoc
WHERE { 
  # ?lexp event:time [ rdfs:label ?when ; edtf:century edtfdata:Century.19 ; edtf:yearOfCentury/rdf:value ?yoc ].
  # ?lexp dc:subject ?perf.
  # ?perf event:place ?place.
  # ?place rdfs:label ?placelabel.
  SERVICE <https://dbpedia.org/sparql/>
     { ?place geo:lat ?lat .
       # ?place geo:long ?long .}
  FILTER ( ?yoc >= 32 && ?yoc <= 38 )
}"""

# set the query
sparql_wd.setQuery(place)
# set the returned format
sparql_wd.setReturnFormat(JSON)
# get the results
results = sparql_wd.query().convert()

results
# Out:
# {'head': {'vars': ['perf', 'place', 'placelabel', 'lat', 'long', 'yoc']},
#  'results': {'bindings': [{'perf': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/performance/7045ccc414dedaadb1d874cfe548a78e/1446306081238'},
#     'place': {'type': 'uri', 'value': 'http://dbpedia.org/resource/London'},
#     'placelabel': {'type': 'literal', 'value': 'London'},
#     'lat': {'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'type': 'literal',
#      'value': '51.5072'},
#     'long': {'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'type': 'literal',
#      'value': '-0.1275'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '33'}},
#    {'perf': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/performance/6c7ec733c1945c87eda522364004be5f/1449058285194'},
#     'place': {'type': 'uri', 'value': 'http://dbpedia.org/resource/London'},
#     'placelabel': {'type': 'literal', 'value': 'London'},
#     'lat': {'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'type': 'literal',
#      'value': '51.5072'},
#     'long': {'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'type': 'literal',
#      'value': '-0.1275'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '36'}},
#    {'perf': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/performance/7715032619a9476246f8cfb8cf564da0/1446380769982'},
#     'place': {'type': 'uri', 'value': 'http://dbpedia.org/resource/London'},
#     'placelabel': {'type': 'literal', 'value': 'London'},
#     'lat': {'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'type': 'literal',
#      'value': '51.5072'},
#     'long': {'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'type': 'literal',
#      'value': '-0.1275'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '34'}},
#    {'perf': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/performance/5f0ed4fa0ce59252275ce0335c1eeb1a/1446402619787'},
#     'place': {'type': 'uri', 'value': 'http://dbpedia.org/resource/London'},
#     'placelabel': {'type': 'literal', 'value': 'London'},
#     'lat': {'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'type': 'literal',
#      'value': '51.5072'},
#     'long': {'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'type': 'literal',
#      'value': '-0.1275'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '35'}},
#    {'perf': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/performance
},
#     'place': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Basel'},
#     'placelabel': {'type': 'literal', 'value': 'Basel'},
#     'lat': {'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'type': 'literal',
#      'value': '47.5547'},
#     'long': {'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'type': 'literal',
#      'value': '7.59056'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '38'}},
#    {'perf': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/performance/99fe88e5b3c0129447d0af7109ed1db3/1450117304639'},
#     'place': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Basel'},
#     'placelabel': {'type': 'literal', 'value': 'Basel'},
#     'lat': {'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'type': 'literal',
#      'value': '47.5547'},
#     'long': {'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'type': 'literal',
#      'value': '7.59056'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '38'}},
#    {'perf': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/performance/http://data.open.ac.uk/led/performance/Die+Zauberfl%25C3%25B6te+(,+performance+of)/1393498367794/1414585133637'},
#     'place': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Basel'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Basel'},
#     'lat': {'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'type': 'literal',
#      'value': '47.5547'},
#     'long': {'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'type': 'literal',
#      'value': '7.59056'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '34'}},
#    {'perf': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/performance/99fe88e5b3c0129447d0af7109ed1db3/1450116247853'},
#     'place': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Basel'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Basel'},
#     'lat': {'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'type': 'literal',
#      'value': '47.5547'},
#     'long': {'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'type': 'literal',
#      'value': '7.59056'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '38'}},
#    {'perf': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/performance/99fe88e5b3c0129447d0af7109ed1db3/1450117304639'},
#     'place': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Basel'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Basel'},
#     'lat': {'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'type': 'literal',
#      'value': '47.5547'},
#     'long': {'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'type': 'literal',
#      'value': '7.59056'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '38'}},
#    {'perf': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/performance/http://data.open.ac.uk/led/music/Viola+Concerto/1422901793319/1424423200868'},
#     'place': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Edinburg,_Virginia'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Edinburg, Virginia'},
#     'lat': {'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'type': 'literal',
#      'value': '38.8225'},
#     'long': {'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'type': 'literal',
#      'value': '-78.5653'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '32'}},
#    {'perf': {'type': 'uri',
#      'value': "http://data.open.ac.uk/led/performance/http://data.open.ac.uk/led/music/'Stormy+Weather'/1429377484433/1429377484444"},
#     'place': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/London_Palladium'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'London Palladium'},
#     'lat': {'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'type': 'literal',
#      'value': '51.5149'},
#     'long': {'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'type': 'literal',
#      'value': '-0.140806'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '33'}},
#    {'perf': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/performance/c138e6967b640db1f4a4046489c57b2b/1448984450210'},
#     'place': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Pasadena,_California'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Pasadena, California'},
#     'lat': {'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'type': 'literal',
#      'value': '34.1561'},
#     'long': {'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'type': 'literal',
#      'value': '-118.132'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '36'}},
#    {'perf': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/performance/bd9c2bd4451d05dbcf7c19e265b7399c/1446754006600'},
#     'place': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Aix-en-Provence'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Aix en Provence'},
#     'lat': {'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'type': 'literal',
#      'value': '43.5263'},
#     'long': {'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'type': 'literal',
#      'value': '5.44543'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '35'}},
#    {'perf': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/performance/bd9c2bd4451d05dbcf7c19e265b7399c/1446754006600'},
#     'place': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Aix-en-Provence'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Aix-en-Provence'},
#     'lat': {'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'type': 'literal',
#      'value': '43.5263'},
#     'long': {'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'type': 'literal',
#      'value': '5.44543'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '35'}},
#    {'perf': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/performance/b55dc2e687b71c9d9570e6d7d0430d45/1477516068662'},
#     'place': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Salzburg'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Salzburg'},
#     'lat': {'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'type': 'literal',
#      'value': '47.8'},
#     'long': {'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'type': 'literal',
#      'value': '13.0333'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '37'}},
#    {'perf': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/performance/http://data.open.ac.uk/led/music/Masses+and+Mozart+operas+in+Salzburg/1409766031751/1409766031757'},
#     'place': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Salzburg'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Salzburg'},
#     'lat': {'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'type': 'literal',
#      'value': '47.8'},
#     'long': {'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'type': 'literal',
#      'value': '13.0333'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '32'}},
#    {'perf': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/performance/fandango+(,+performance+of)/1404493541742'},
#     'place': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Province_of_Zamora'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Province of Zamora'},
#     'lat': {'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'type': 'literal',
#      'value': '41.75'},
#     'long': {'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'type': 'literal',
#      'value': '-6.0'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '35'}},
#    {'perf': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/performance/Irish+reel+(,+performance+of)/1404493523476'},
#     'place': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Province_of_Zamora'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Province of Zamora'},
#     'lat': {'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'type': 'literal',
#      'value': '41.75'},
#     'long': {'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'type': 'literal',
#      'value': '-6.0'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '35'}},
#    {'perf': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/performance/Spanish+folk+songs+(,+performance+of)/1404493556208'},
#     'place': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Province_of_Zamora'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Province of Zamora'},
#     'lat': {'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'type': 'literal',
#      'value': '41.75'},
#     'long': {'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'type': 'literal',
#      'value': '-6.0'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '35'}},
#    {'perf': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/performance/pasodoble+(,+performance+of)/1404405074711'},
#     'place': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Zamora,_Spain'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Zamora, Spain'},
#     'lat': {'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'type': 'literal',
#      'value': '41.4989'},
#     'long': {'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'type': 'literal',
#      'value': '-5.75556'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '35'}},
#    {'perf': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/performance/Vienna+Woods+(,+performance+of)/1404227361012'},
#     'place': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Zamora,_Spain'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Zamora, Spain'},
#     'lat': {'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'type': 'literal',
#      'value': '41.4989'},
#     'long': {'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'type': 'literal',
#      'value': '-5.75556'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '35'}},
#    {'perf': {'type': 'uri',
#      'value': 'http://data.open.ac.uk/led/performance/http://data.open.ac.uk/led/music/Concerto+no.+1+in+F+minor,+op.+73/1422199913719/1422200640521'},
#     'place': {'type': 'uri', 'value': 'http://dbpedia.org/resource/New_Cross'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'New Cross'},
#     'lat': {'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'type': 'literal',
#      'value': '51.4709'},
#     'long': {'datatype': 'http://www.w3.org/2001/XMLSchema#float',
#      'type': 'literal',
#      'value': '-0.0337'},
#     'yoc': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '33'}}]}}

# %% [markdown]
# # Sentiment analysis with [Scikit-learn](https://scikit-learn.org/stable/):
#
# ❗ Made an attempt but all is classified as positive. maybe we should use more sentiment categories. <br>
# Using a training dataset downloaded from [kaggle](https://www.kaggle.com/nltkdata/movie-review):

# %%
import pandas as pd
df = pd.read_csv('movie_review.csv')

# %%
df.fillna("")
# Out:
#        fold_id cv_tag  html_id  sent_id  \
# 0            0  cv000    29590        0
# 1            0  cv000    29590        1
# 2            0  cv000    29590        2
# 3            0  cv000    29590        3
# 4            0  cv000    29590        4
# ...        ...    ...      ...      ...
# 28673        8  cv871    24888        8
# 28674        8  cv871    24888        9
# 28675        8  cv871    24888       10
# 28676        8  cv871    24888       11
# 28677        8  cv871    24888       12
#
#                                                     text  tag
# 0      films adapted from comic books have had plenty...  pos
# 1      for starters , it was created by alan moore ( ...  pos
# 2      to say moore and campbell thoroughly researche...  pos
# 3      the book ( or " graphic novel , " if you will ...  pos
# 4      in other words , don't dismiss this film becau...  pos
# ...                                                  ...  ...
# 28673  reluctantly , he sets up nyah to be rescued fr...  pos
# 28674  ethan must race against time to keep ambrose f...  pos
# 28675  although the first mission : impossible film w...  pos
# 28676  that problem has been rectified in the sequel ...  pos
# 28677                      the end result is one of the
#
# [28678 rows x 6 columns]

# %%
X = df['text'] 
y = df['tag']

# %%
from numpy import random,array

# %%
random.seed(0)

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
from sklearn.feature_extraction.text import CountVectorizer
vect=CountVectorizer(ngram_range=(1,2)) 
X=vect.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3)

# %%
from sklearn.naive_bayes import BernoulliNB

# %%
model = BernoulliNB()

# %%
model.fit(X_train, y_train)
# Out:
# BernoulliNB()

# %%
from sklearn.metrics import accuracy_score

# %%
#errori = accuracy_score(y_test, p_test)
#print(errori)

# %% [markdown]
# How to analyze a single query:

# %%
q=array(['good wonderful film']) 
q=vect.transform(q)

# %%
print(model.predict(q))
# Out:
# ['pos']

# %% [markdown]
# ## CQ11 What did people ‘make of’, how did they react to, e.g. music?

# %%
# CQ 11
#retrieve texts for doing sentiment analysis
query = """
PREFIX dc: <http://purl.org/dc/terms/>
PREFIX edtf: <http://data.open.ac.uk/edtf/ontology/>
PREFIX edtfdata: <http://data.open.ac.uk/time/edtf/>
PREFIX event: <http://purl.org/NET/c4dm/event.owl#>
PREFIX led: <http://led.kmi.open.ac.uk/term/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX schema: <http://schema.org/>
prefix mo:<http://purl.org/ontology/mo/>
prefix db:<http://dbpedia.org/ontology/>
prefix uk:<http://data.open.ac.uk/ukresearchproject/ontology/>
prefix ox:<http://vocab.ox.ac.uk/projectfunding#>
  
SELECT DISTINCT  ?songlabel ?text ?date ?description ?when ?yoc
WHERE { 
  # ?lexp event:time [ rdfs:label ?when ; edtf:century edtfdata:Century.19 ; edtf:yearOfCentury/rdf:value ?yoc ].
  
  # ?lexp  dc:subject ?perf.
  # ?perf mo:performance_of ?song.
  # ?song rdfs:label ?songlabel.
  # ?lexp led:has_evidence_text ?text.
  FILTER ( ?yoc >= 32 && ?yoc <= 38 ) 
}
"""
# set the query
sparql_wd.setQuery(query)
# set the returned format
sparql_wd.setReturnFormat(JSON)
# get the results
results = sparql_wd.query().convert()

# %%
# easier way to obtain a dataframe
import pandas as pds
df_text = pds.DataFrame(results['results']['bindings'])
df_text.applymap(lambda x: x['value']) #drop the duplicates! maybe selecting the perf uri instead of songlabel
# Out:
#                          songlabel  \
# 0                Die Meistersinger
# 1                G��tterd��mmerung
# 2           Der ing des Nibelungen
# 3          Der Ring des Nibelungen
# 4           Ring of the Nibelungen
# ..                             ...
# 379            String Quartet No.9
# 380              unspecified songs
# 381                          Wasps
# 382  The Planets, Op. 32 - Jupiter
# 383                Tandava Nrittya
#
#                                                   text                   when  \
# 0    Listen to a Wagner Prom after dinner on a very...     19 September, 1932
# 1    Listen to a Wagner Prom after dinner on a very...     19 September, 1932
# 2    In the April season Flagstad was back to delig...            April, 1937
# 3    In the April season Flagstad was back to delig...            April, 1937
# 4    In the April season Flagstad was back to delig...            April, 1937
# ..                                                 ...                    ...
# 379  In contrast with most musical audiences this s...        5 October, 1937
# 380  R.C.M. Jubilee. concert at 3.0 attended by T.M...  9 May, 1933, 03:00 PM
# 381  R.C.M. Jubilee. concert at 3.0 attended by T.M...  9 May, 1933, 03:00 PM
# 382  R.C.M. Jubilee. concert at 3.0 attended by T.M...  9 May, 1933, 03:00 PM
# 383  I go to Amb. Th. at 8.45 - ticket paid for by ...  6 May, 1933, 08:45 PM
#
#     yoc
# 0    32
# 1    32
# 2    37
# 3    37
# 4    37
# ..   ..
# 379  37
# 380  33
# 381  33
# 382  33
# 383  33
#
# [384 rows x 4 columns]

# %%
# sentiment analysis with scikit learn -> they're all positive -> shall we do another kind of analysis?
for result in results["results"]["bindings"]:
    q =array([result["text"]["value"]])
    q=vect.transform(q)
    print(result["songlabel"]["value"], "\n",model.predict(q), " ->",[result["text"]["value"]])

# %%
df_sent = pd.DataFrame(columns=['songlabel','sentiment'])
idx=0
for result in results["results"]["bindings"]:
    
    q =array([result["text"]["value"]])
    q=vect.transform(q)
    sent=str(model.predict(q)).replace("[","").replace("]","")
    df_sent.loc[idx] = [result["songlabel"]["value"],sent]
    idx+=1

# %%
df_sent
# Out:
#                          songlabel sentiment
# 0                Die Meistersinger     'pos'
# 1                G��tterd��mmerung     'pos'
# 2           Der ing des Nibelungen     'pos'
# 3          Der Ring des Nibelungen     'pos'
# 4           Ring of the Nibelungen     'pos'
# ..                             ...       ...
# 379            String Quartet No.9     'pos'
# 380              unspecified songs     'pos'
# 381                          Wasps     'pos'
# 382  The Planets, Op. 32 - Jupiter     'pos'
# 383                Tandava Nrittya     'pos'
#
# [384 rows x 2 columns]

# %% [markdown]
# ## CQ12: Who was the author of a piece of music? e.g. can we identify it by its incipit?

# %%
#CQ12: Who was the author of a piece of music?
# retrieve the composers of performances
query = """
PREFIX dc: <http://purl.org/dc/terms/>
PREFIX edtf: <http://data.open.ac.uk/edtf/ontology/>
PREFIX edtfdata: <http://data.open.ac.uk/time/edtf/>
PREFIX event: <http://purl.org/NET/c4dm/event.owl#>
PREFIX led: <http://led.kmi.open.ac.uk/term/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX schema: <http://schema.org/>
prefix mo:<http://purl.org/ontology/mo/>
prefix db:<http://dbpedia.org/ontology/>
prefix uk:<http://data.open.ac.uk/ukresearchproject/ontology/>
prefix ox:<http://vocab.ox.ac.uk/projectfunding#>
  
SELECT DISTINCT  ?perf ?songlabel ?author ?yoc
WHERE { 
  # ?lexp event:time [ rdfs:label ?when ; edtf:century edtfdata:Century.19 ; edtf:yearOfCentury/rdf:value ?yoc ]. 
  # ?lexp  dc:subject ?perf.
  # ?perf mo:performance_of ?song.
  # ?song rdfs:label ?songlabel.
  # ?song mo:composer ?author.
  FILTER ( ?yoc >= 32 && ?yoc <= 38 )
  }
"""
# set the query
sparql_wd.setQuery(query)
# set the returned format
sparql_wd.setReturnFormat(JSON)
# get the results
results_author = sparql_wd.query().convert()

# %%
df_author = pds.DataFrame(results_author['results']['bindings'])
df_author.applymap(lambda x: x['value'])
# Out:
#                                                   perf  \
# 0    http://data.open.ac.uk/led/performance/http://...
# 1    http://data.open.ac.uk/led/performance/http://...
# 2    http://data.open.ac.uk/led/performance/http://...
# 3    http://data.open.ac.uk/led/performance/http://...
# 4    http://data.open.ac.uk/led/performance/http://...
# ..                                                 ...
# 867  http://data.open.ac.uk/led/performance/b88ba9f...
# 868  http://data.open.ac.uk/led/performance/87d23f9...
# 869  http://data.open.ac.uk/led/performance/87d23f9...
# 870  http://data.open.ac.uk/led/performance/http://...
# 871  http://data.open.ac.uk/led/performance/7bd89f4...
#
#                          songlabel  \
# 0                Die Meistersinger
# 1                G��tterd��mmerung
# 2                   Symphony No. 9
# 3                  Aus mein Lieben
# 4               Charterhouse Suite
# ..                             ...
# 867                Hungarian March
# 868          Introduction to Valse
# 869          Introduction to Valse
# 870  The Planets, Op. 32 - Jupiter
# 871      unspecified Strauss songs
#
#                                                 author yoc
# 0           http://dbpedia.org/resource/Richard_Wagner  32
# 1           http://dbpedia.org/resource/Richard_Wagner  32
# 2     http://dbpedia.org/resource/Ludwig_van_Beethoven  32
# 3    http://data.open.ac.uk/led/person/Smetana/1434...  32
# 4    http://dbpedia.org/resource/Ralph_Vaughan_Will...  32
# ..                                                 ...  ..
# 867         http://dbpedia.org/resource/Richard_Wagner  34
# 868         http://dbpedia.org/resource/Hector_Berlioz  34
# 869         http://dbpedia.org/resource/Richard_Wagner  34
# 870           http://dbpedia.org/resource/Gustav_Holst  33
# 871        http://dbpedia.org/resource/Richard_Strauss  34
#
# [872 rows x 4 columns]

# %% [markdown]
# ## CQ14: What is the cause of a change, e.g. increasing number of concerts over time?

# %%
#what was the cause of a change?
#number of performances per medium pre - war
query = """ PREFIX dc: <http://purl.org/dc/terms/>
PREFIX edtf: <http://data.open.ac.uk/edtf/ontology/>
PREFIX edtfdata: <http://data.open.ac.uk/time/edtf/>
PREFIX event: <http://purl.org/NET/c4dm/event.owl#>
PREFIX led: <http://led.kmi.open.ac.uk/term/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX schema: <http://schema.org/>
prefix mo:<http://purl.org/ontology/mo/>
prefix db:<http://dbpedia.org/ontology/>
prefix uk:<http://data.open.ac.uk/ukresearchproject/ontology/>
prefix ox:<http://vocab.ox.ac.uk/projectfunding#>
prefix foaf:<http://xmlns.com/foaf/0.1/>

select   ?medium (count(?lexp)as ?exp) 
WHERE {
  # ?lexp event:time [ rdfs:label ?when ; edtf:century edtfdata:Century.19 ; edtf:yearOfCentury/rdf:value ?yoc ].
   # ?lexp led:has_medium ?medium.
  FILTER ( ?yoc >= 32 && ?yoc <= 38 ) .   
} group by ?medium 
"""
# set the query
sparql_wd.setQuery(query)
# set the returned format
sparql_wd.setReturnFormat(JSON)
# get the results
results = sparql_wd.query().convert()

# %%
import pandas as pds
df_medium_pre = pds.DataFrame(results['results']['bindings'])
df_medium_pre.applymap(lambda x: x['value'])
# Out:
#                                             medium  exp
# 0  http://led.kmi.open.ac.uk/term/Medium.Broadcast  173
# 1       http://led.kmi.open.ac.uk/term/Medium.Live  309
# 2   http://led.kmi.open.ac.uk/term/Medium.Playback   39

# %%
#number of performances per medium during war
query = """ PREFIX dc: <http://purl.org/dc/terms/>
PREFIX edtf: <http://data.open.ac.uk/edtf/ontology/>
PREFIX edtfdata: <http://data.open.ac.uk/time/edtf/>
PREFIX event: <http://purl.org/NET/c4dm/event.owl#>
PREFIX led: <http://led.kmi.open.ac.uk/term/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX schema: <http://schema.org/>
prefix mo:<http://purl.org/ontology/mo/>
prefix db:<http://dbpedia.org/ontology/>
prefix uk:<http://data.open.ac.uk/ukresearchproject/ontology/>
prefix ox:<http://vocab.ox.ac.uk/projectfunding#>
prefix foaf:<http://xmlns.com/foaf/0.1/>

select   ?medium (count(?lexp)as ?exp) 
WHERE {
  # ?lexp event:time [ rdfs:label ?when ; edtf:century edtfdata:Century.19 ; edtf:yearOfCentury/rdf:value ?yoc ].
   # ?lexp led:has_medium ?medium.
  FILTER ( ?yoc >= 39 && ?yoc <= 45 ) .   
} group by ?medium 
"""
# set the query
sparql_wd.setQuery(query)
# set the returned format
sparql_wd.setReturnFormat(JSON)
# get the results
results = sparql_wd.query().convert()
import pandas as pds
df_medium_war= pds.DataFrame(results['results']['bindings'])
df_medium_war.applymap(lambda x: x['value'])
# Out:
#                                             medium  exp
# 0       http://led.kmi.open.ac.uk/term/Medium.Live  121
# 1  http://led.kmi.open.ac.uk/term/Medium.Broadcast   13
# 2   http://led.kmi.open.ac.uk/term/Medium.Playback   15

# %%
#number of performances per medium during war
query = """ PREFIX dc: <http://purl.org/dc/terms/>
PREFIX edtf: <http://data.open.ac.uk/edtf/ontology/>
PREFIX edtfdata: <http://data.open.ac.uk/time/edtf/>
PREFIX event: <http://purl.org/NET/c4dm/event.owl#>
PREFIX led: <http://led.kmi.open.ac.uk/term/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX schema: <http://schema.org/>
prefix mo:<http://purl.org/ontology/mo/>
prefix db:<http://dbpedia.org/ontology/>
prefix uk:<http://data.open.ac.uk/ukresearchproject/ontology/>
prefix ox:<http://vocab.ox.ac.uk/projectfunding#>
prefix foaf:<http://xmlns.com/foaf/0.1/>

select   ?medium (count(?lexp)as ?exp) 
WHERE {
  # ?lexp event:time [ rdfs:label ?when ; edtf:century edtfdata:Century.19 ; edtf:yearOfCentury/rdf:value ?yoc ].
   # ?lexp led:has_medium ?medium.
  FILTER ( ?yoc >= 46 && ?yoc <= 52 ) .   
} group by ?medium 
"""
# set the query
sparql_wd.setQuery(query)
# set the returned format
sparql_wd.setReturnFormat(JSON)
# get the results
results = sparql_wd.query().convert()
import pandas as pds
df_medium_after= pds.DataFrame(results['results']['bindings'])
df_medium_after.applymap(lambda x: x['value'])
# Out:
#                                             medium  exp
# 0       http://led.kmi.open.ac.uk/term/Medium.Live  134
# 1  http://led.kmi.open.ac.uk/term/Medium.Broadcast   14
# 2   http://led.kmi.open.ac.uk/term/Medium.Playback    8

# %% [markdown]
# ## CQ 10 **QUERIES on brass bands**
#
# We tried retrieving data on brass bands but we have found a few stuff . We have tried applying the research questions to this topic.
#
#
#
# CQ10: How does the world of brass bands connect with that of elite music? <br>

# %%
# retrieving the listening experiences of a brass band performance
query = """
PREFIX dc: <http://purl.org/dc/terms/>
PREFIX edtf: <http://data.open.ac.uk/edtf/ontology/>
PREFIX edtfdata: <http://data.open.ac.uk/time/edtf/>
PREFIX event: <http://purl.org/NET/c4dm/event.owl#>
PREFIX led: <http://led.kmi.open.ac.uk/term/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX schema: <http://schema.org/>
prefix mo:<http://purl.org/ontology/mo/>
prefix db:<http://dbpedia.org/ontology/>
prefix uk:<http://data.open.ac.uk/ukresearchproject/ontology/>
prefix ox:<http://vocab.ox.ac.uk/projectfunding#>
  
  
SELECT DISTINCT ?lexp ?label ?date ?genre_label ?performer_label ?place_label
WHERE { 
  # ?lexp event:time ?when.
  # ?when rdfs:label ?date.
  # ?lexp  dc:subject ?perf.
  # ?lexp event:place ?place.
  # ?place rdfs:label ?place_label. 
  # ?perf rdfs:label ?label;
    	mo:genre ?genre;
    	mo:performer ?performer.
  # ?genre rdfs:label ?genre_label.
  # ?performer rdfs:label ?performer_label.
  
  FILTER(REGEX(?label, "brass band" , "i"))
  FILTER langMatches( lang(?place_label), "en" ) 
  FILTER langMatches( lang(?performer_label), "en" ) 
  FILTER langMatches( lang(?genre_label), "en" ) 
	 }
"""
# set the query
sparql_wd.setQuery(query)
# set the returned format
sparql_wd.setReturnFormat(JSON)
# get the results
results_brass = sparql_wd.query().convert()

# %% [markdown]
# We don't seem to have brass band performances in the period of the 2nd world war (pre-during-after): ⬇

# %%
# manipulate the result
for result in results_brass["results"]["bindings"]:
    print(result["label"]["value"]," DATE: ", result["date"]["value"]," PERFORMER: ",result["performer_label"]["value"]," GENRE: ",result["genre_label"]["value"]," PLACE: ",result["place_label"]["value"], "\n")
# Out:
# performance of 'New Orleans Brass Band music'  DATE:  1895  PERFORMER:  Buddy Bolden  GENRE:  Jazz  PLACE:  New Orleans
#
# performance of 'New Orleans Brass Band music'  DATE:  early 20th Century  PERFORMER:  Buddy Petit  GENRE:  Fanfare  PLACE:  New Orleans
#
# performance of 'New Orleans Brass Band music'  DATE:  early 20th Century  PERFORMER:  Buddy Petit  GENRE:  Flourish  PLACE:  New Orleans
#
# performance of 'New Orleans Brass Band music'  DATE:  early 20th Century  PERFORMER:  Frankie Duson  GENRE:  Fanfare  PLACE:  New Orleans
#
# performance of 'New Orleans Brass Band music'  DATE:  early 20th Century  PERFORMER:  Frankie Duson  GENRE:  Flourish  PLACE:  New Orleans
#
# performance of 'New Orleans Brass Band music'  DATE:  early 20th Century  PERFORMER:  Kid Rena  GENRE:  Fanfare  PLACE:  New Orleans
#
# performance of 'New Orleans Brass Band music'  DATE:  early 20th Century  PERFORMER:  Kid Rena  GENRE:  Flourish  PLACE:  New Orleans
#
# performance of 'New Orleans Brass Band music'  DATE:  early 20th Century  PERFORMER:  Chris Kelly  GENRE:  Fanfare  PLACE:  New Orleans
#
# performance of 'New Orleans Brass Band music'  DATE:  early 20th Century  PERFORMER:  Chris Kelly  GENRE:  Flourish  PLACE:  New Orleans
#
# performance of 'New Orleans Brass Band music'  DATE:  early 20th Century  PERFORMER:  Bunk Johnson  GENRE:  Fanfare  PLACE:  New Orleans
#
# performance of 'New Orleans Brass Band music'  DATE:  early 20th Century  PERFORMER:  Bunk Johnson  GENRE:  Flourish  PLACE:  New Orleans
#
# performance of 'Walk��re for brass band'  DATE:  1897  PERFORMER:  Brass band  GENRE:  Opera  PLACE:  Earls Court Exhibition Centre
#
# performance of 'Walk��re for brass band'  DATE:  1897  PERFORMER:  Brass band  GENRE:  Operatic  PLACE:  Earls Court Exhibition Centre
#
# performance of 'New Orleans Brass Band music'  DATE:  late 19th Century  PERFORMER:  Fice Quiyrit  GENRE:  March (music)  PLACE:  New Orleans
#
# performance of 'New Orleans Brass Band music'  DATE:  late 19th Century  PERFORMER:  The Excelsior Band  GENRE:  March (music)  PLACE:  New Orleans
#
# performance of 'Brass band funeral music'  DATE:  early 20th Century  PERFORMER:  Tuxedo Brass Band  GENRE:  Music of New Orleans  PLACE:  New Orleans
#
# performance of 'New Orleans Brass Band music'  DATE:  early 20th Century  PERFORMER:  Buddy Petit  GENRE:  Music of New Orleans  PLACE:  New Orleans
#
# performance of 'New Orleans Brass Band music'  DATE:  late 19th Century  PERFORMER:  Fice Quiyrit  GENRE:  Music of New Orleans  PLACE:  New Orleans
#
# performance of 'New Orleans Brass Band music'  DATE:  early 20th Century  PERFORMER:  Frankie Duson  GENRE:  Music of New Orleans  PLACE:  New Orleans
#
# performance of 'New Orleans Brass Band music'  DATE:  late 19th Century  PERFORMER:  The Excelsior Band  GENRE:  Music of New Orleans  PLACE:  New Orleans
#
# performance of 'brass band military music'  DATE:  early 20th Century  PERFORMER:  Onward Brass Band  GENRE:  Music of New Orleans  PLACE:  New Orleans
#
# performance of 'New Orleans Brass Band music'  DATE:  early 20th Century  PERFORMER:  Kid Rena  GENRE:  Music of New Orleans  PLACE:  New Orleans
#
# performance of 'New Orleans Brass Band music'  DATE:  early 20th Century  PERFORMER:  Chris Kelly  GENRE:  Music of New Orleans  PLACE:  New Orleans
#
# performance of 'New Orleans Brass Band music'  DATE:  early 20th Century  PERFORMER:  Bunk Johnson  GENRE:  Music of New Orleans  PLACE:  New Orleans
#
# performance of 'brass band dance music'  DATE:  early 20th Century  PERFORMER:  Onward Brass Band  GENRE:  Swing music  PLACE:  New Orleans
#
# performance of 'New Orleans Brass Band music'  DATE:  early 20th Century  PERFORMER:  Buddy Petit  GENRE:  Music of New Orleans  PLACE:  New Orleans
#
# performance of 'New Orleans Brass Band music'  DATE:  early 20th Century  PERFORMER:  George Lewis  GENRE:  Music of New Orleans  PLACE:  New Orleans
#
# performance of 'New Orleans Brass Band music'  DATE:  early 20th Century  PERFORMER:  Buddy Petit  GENRE:  Music of New Orleans  PLACE:  New Orleans
#
# performance of 'New Orleans Brass Band music'  DATE:  early 20th Century  PERFORMER:  Joe "King" Oliver  GENRE:  Music of New Orleans  PLACE:  New Orleans
#
# performance of 'New Orleans Brass Band music'  DATE:  early 20th Century  PERFORMER:  Onward Brass Band  GENRE:  Music of New Orleans  PLACE:  New Orleans
#
# performance of 'New Orleans Brass Band music'  DATE:  early 20th Century  PERFORMER:  Mutt Carey  GENRE:  Music of New Orleans  PLACE:  New Orleans
#
# performance of 'New Orleans Brass Band music'  DATE:  early 20th Century  PERFORMER:  Tuxedo Big Band  GENRE:  Music of New Orleans  PLACE:  New Orleans
#
# performance of 'New Orleans Brass Band music'  DATE:  late 19th Century  PERFORMER:  Fice Quiyrit  GENRE:  Parade Music  PLACE:  New Orleans
#
# performance of 'New Orleans Brass Band music'  DATE:  late 19th Century  PERFORMER:  The Excelsior Band  GENRE:  Parade Music  PLACE:  New Orleans

# %%
#retrieving the environment of performances
query= """
PREFIX dc: <http://purl.org/dc/terms/>
PREFIX edtf: <http://data.open.ac.uk/edtf/ontology/>
PREFIX edtfdata: <http://data.open.ac.uk/time/edtf/>
PREFIX event: <http://purl.org/NET/c4dm/event.owl#>
PREFIX led: <http://led.kmi.open.ac.uk/term/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX schema: <http://schema.org/>
prefix mo:<http://purl.org/ontology/mo/>
prefix db:<http://dbpedia.org/ontology/>
prefix uk:<http://data.open.ac.uk/ukresearchproject/ontology/>
prefix ox:<http://vocab.ox.ac.uk/projectfunding#>
  
SELECT DISTINCT ?lexp ?label ?env
WHERE { 
  # ?lexp event:time ?when.
  # ?when rdfs:label ?date.
  # ?lexp  dc:subject ?perf.
  # ?perf rdfs:label ?label.
  # ?lexp led:has_environment ?env.
  
  FILTER(REGEX(?label, "brass" , "i"))
  
	 }
"""
# set the query
sparql_wd.setQuery(query)
# set the returned format
sparql_wd.setReturnFormat(JSON)
# get the results
results= sparql_wd.query().convert()

# %%
# manipulate the result
for result in results["results"]["bindings"]:
    print(result["lexp"]["value"]," environment: ",result["env"]["value"], "\n")
# Out:
# http://data.open.ac.uk/led/lexp/1433408473434  environment:  http://led.kmi.open.ac.uk/term/ListeningEnvironment.Outdoor
#
# http://data.open.ac.uk/led/lexp/1382351150  environment:  http://led.kmi.open.ac.uk/term/ListeningEnvironment.Accompanied
#
# http://data.open.ac.uk/led/lexp/1382351150  environment:  http://led.kmi.open.ac.uk/term/ListeningEnvironment.Outdoor
#
# http://data.open.ac.uk/led/lexp/1382351150  environment:  http://led.kmi.open.ac.uk/term/ListeningEnvironment.Public
#
# http://data.open.ac.uk/led/lexp/1431469593713  environment:  http://led.kmi.open.ac.uk/term/ListeningEnvironment.Accompanied
#
# http://data.open.ac.uk/led/lexp/1431469593713  environment:  http://led.kmi.open.ac.uk/term/ListeningEnvironment.Outdoor
#
# http://data.open.ac.uk/led/lexp/1431469593713  environment:  http://led.kmi.open.ac.uk/term/ListeningEnvironment.Public
#
# http://data.open.ac.uk/led/lexp/1436017047829  environment:  http://led.kmi.open.ac.uk/term/ListeningEnvironment.Accompanied
#
# http://data.open.ac.uk/led/lexp/1436017047829  environment:  http://led.kmi.open.ac.uk/term/ListeningEnvironment.Public
#
# http://data.open.ac.uk/led/lexp/1433412945050  environment:  http://led.kmi.open.ac.uk/term/ListeningEnvironment.Accompanied
#
# http://data.open.ac.uk/led/lexp/1433412945050  environment:  http://led.kmi.open.ac.uk/term/ListeningEnvironment.Public
#
# http://data.open.ac.uk/led/lexp/1433341215423  environment:  http://led.kmi.open.ac.uk/term/ListeningEnvironment.Accompanied
#
# http://data.open.ac.uk/led/lexp/1433341215423  environment:  http://led.kmi.open.ac.uk/term/ListeningEnvironment.Outdoor
#
# http://data.open.ac.uk/led/lexp/1433341215423  environment:  http://led.kmi.open.ac.uk/term/ListeningEnvironment.Public
#
# http://data.open.ac.uk/led/lexp/1433412945050  environment:  http://led.kmi.open.ac.uk/term/ListeningEnvironment.Accompanied
#
# http://data.open.ac.uk/led/lexp/1433412945050  environment:  http://led.kmi.open.ac.uk/term/ListeningEnvironment.Public
#
# http://data.open.ac.uk/led/lexp/1433412232516  environment:  http://led.kmi.open.ac.uk/term/ListeningEnvironment.Accompanied
#
# http://data.open.ac.uk/led/lexp/1433412232516  environment:  http://led.kmi.open.ac.uk/term/ListeningEnvironment.Outdoor
#
# http://data.open.ac.uk/led/lexp/1433412232516  environment:  http://led.kmi.open.ac.uk/term/ListeningEnvironment.Public
#
# http://data.open.ac.uk/led/lexp/1433412232516  environment:  http://led.kmi.open.ac.uk/term/ListeningEnvironment.Accompanied
#
# http://data.open.ac.uk/led/lexp/1433412232516  environment:  http://led.kmi.open.ac.uk/term/ListeningEnvironment.Outdoor
#
# http://data.open.ac.uk/led/lexp/1433412232516  environment:  http://led.kmi.open.ac.uk/term/ListeningEnvironment.Public
#
# http://data.open.ac.uk/led/lexp/1433412945050  environment:  http://led.kmi.open.ac.uk/term/ListeningEnvironment.Accompanied
#
# http://data.open.ac.uk/led/lexp/1433412945050  environment:  http://led.kmi.open.ac.uk/term/ListeningEnvironment.Public
#
# http://data.open.ac.uk/led/lexp/1433413863437  environment:  http://led.kmi.open.ac.uk/term/ListeningEnvironment.Accompanied
#
# http://data.open.ac.uk/led/lexp/1433413863437  environment:  http://led.kmi.open.ac.uk/term/ListeningEnvironment.Outdoor
#
# http://data.open.ac.uk/led/lexp/1433413863437  environment:  http://led.kmi.open.ac.uk/term/ListeningEnvironment.Public
#
# http://data.open.ac.uk/led/lexp/1433417089059  environment:  http://led.kmi.open.ac.uk/term/ListeningEnvironment.Accompanied
#
# http://data.open.ac.uk/led/lexp/1433417089059  environment:  http://led.kmi.open.ac.uk/term/ListeningEnvironment.Outdoor
#
# http://data.open.ac.uk/led/lexp/1433417089059  environment:  http://led.kmi.open.ac.uk/term/ListeningEnvironment.Public
#
# http://data.open.ac.uk/led/lexp/1433434192397  environment:  http://led.kmi.open.ac.uk/term/ListeningEnvironment.Accompanied
#
# http://data.open.ac.uk/led/lexp/1433434192397  environment:  http://led.kmi.open.ac.uk/term/ListeningEnvironment.Outdoor
#
# http://data.open.ac.uk/led/lexp/1433434192397  environment:  http://led.kmi.open.ac.uk/term/ListeningEnvironment.Public
#
# http://data.open.ac.uk/led/lexp/1433342830157  environment:  http://led.kmi.open.ac.uk/term/ListeningEnvironment.Accompanied
#
# http://data.open.ac.uk/led/lexp/1433342830157  environment:  http://led.kmi.open.ac.uk/term/ListeningEnvironment.Public
#
# http://data.open.ac.uk/led/lexp/1433526879389  environment:  http://led.kmi.open.ac.uk/term/ListeningEnvironment.Accompanied
#
# http://data.open.ac.uk/led/lexp/1433526879389  environment:  http://led.kmi.open.ac.uk/term/ListeningEnvironment.Outdoor
#
# http://data.open.ac.uk/led/lexp/1433526879389  environment:  http://led.kmi.open.ac.uk/term/ListeningEnvironment.Public
#
# http://data.open.ac.uk/led/lexp/1433342105048  environment:  http://led.kmi.open.ac.uk/term/ListeningEnvironment.Accompanied
#
# http://data.open.ac.uk/led/lexp/1433342105048  environment:  http://led.kmi.open.ac.uk/term/ListeningEnvironment.Indoor
#
# http://data.open.ac.uk/led/lexp/1433342105048  environment:  http://led.kmi.open.ac.uk/term/ListeningEnvironment.Outdoor
#
# http://data.open.ac.uk/led/lexp/1433342105048  environment:  http://led.kmi.open.ac.uk/term/ListeningEnvironment.Public
#
# http://data.open.ac.uk/led/lexp/1406801467891  environment:  http://led.kmi.open.ac.uk/term/ListeningEnvironment.Accompanied
#
# http://data.open.ac.uk/led/lexp/1406801467891  environment:  http://led.kmi.open.ac.uk/term/ListeningEnvironment.Public
#
# http://data.open.ac.uk/led/lexp/1435834748251  environment:  http://led.kmi.open.ac.uk/term/ListeningEnvironment.Accompanied
#
# http://data.open.ac.uk/led/lexp/1435834748251  environment:  http://led.kmi.open.ac.uk/term/ListeningEnvironment.Domestic
#
# http://data.open.ac.uk/led/lexp/1435834748251  environment:  http://led.kmi.open.ac.uk/term/ListeningEnvironment.Indoor
#
# http://data.open.ac.uk/led/lexp/1433416523766  environment:  http://led.kmi.open.ac.uk/term/ListeningEnvironment.Accompanied
#
# http://data.open.ac.uk/led/lexp/1433416523766  environment:  http://led.kmi.open.ac.uk/term/ListeningEnvironment.Outdoor
#
# http://data.open.ac.uk/led/lexp/1433416523766  environment:  http://led.kmi.open.ac.uk/term/ListeningEnvironment.Public
#
# http://data.open.ac.uk/led/lexp/1436023057602  environment:  http://led.kmi.open.ac.uk/term/ListeningEnvironment.Accompanied
#
# http://data.open.ac.uk/led/lexp/1436023057602  environment:  http://led.kmi.open.ac.uk/term/ListeningEnvironment.Indoor
#
# http://data.open.ac.uk/led/lexp/1436023057602  environment:  http://led.kmi.open.ac.uk/term/ListeningEnvironment.Outdoor
#
# http://data.open.ac.uk/led/lexp/1436023057602  environment:  http://led.kmi.open.ac.uk/term/ListeningEnvironment.Public
#
# http://data.open.ac.uk/led/lexp/1433436283678  environment:  http://led.kmi.open.ac.uk/term/ListeningEnvironment.Accompanied
#
# http://data.open.ac.uk/led/lexp/1433436283678  environment:  http://led.kmi.open.ac.uk/term/ListeningEnvironment.Outdoor
#
# http://data.open.ac.uk/led/lexp/1433436283678  environment:  http://led.kmi.open.ac.uk/term/ListeningEnvironment.Public
#
# http://data.open.ac.uk/led/lexp/1434399439736  environment:  http://led.kmi.open.ac.uk/term/ListeningEnvironment.Accompanied
#
# http://data.open.ac.uk/led/lexp/1434399439736  environment:  http://led.kmi.open.ac.uk/term/ListeningEnvironment.Indoor
#
# http://data.open.ac.uk/led/lexp/1434399439736  environment:  http://led.kmi.open.ac.uk/term/ListeningEnvironment.Public
#
# http://data.open.ac.uk/led/lexp/1397125124179  environment:  http://led.kmi.open.ac.uk/term/ListeningEnvironment.Accompanied
#
# http://data.open.ac.uk/led/lexp/1397125124179  environment:  http://led.kmi.open.ac.uk/term/ListeningEnvironment.Domestic
#
# http://data.open.ac.uk/led/lexp/1397125124179  environment:  http://led.kmi.open.ac.uk/term/ListeningEnvironment.Indoor
#
# http://data.open.ac.uk/led/lexp/1438252098143  environment:  http://led.kmi.open.ac.uk/term/ListeningEnvironment.Domestic
#
# http://data.open.ac.uk/led/lexp/1438252098143  environment:  http://led.kmi.open.ac.uk/term/ListeningEnvironment.Indoor
#
# http://data.open.ac.uk/led/lexp/1438252098143  environment:  http://led.kmi.open.ac.uk/term/ListeningEnvironment.Solitary

# %% [markdown]
# CQ11: What did people ‘make of’, how did they react to, e.g. music?

# %%
#retrieve texts for doing sentiment analysis
query = """
PREFIX dc: <http://purl.org/dc/terms/>
PREFIX edtf: <http://data.open.ac.uk/edtf/ontology/>
PREFIX edtfdata: <http://data.open.ac.uk/time/edtf/>
PREFIX event: <http://purl.org/NET/c4dm/event.owl#>
PREFIX led: <http://led.kmi.open.ac.uk/term/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX schema: <http://schema.org/>
prefix mo:<http://purl.org/ontology/mo/>
prefix db:<http://dbpedia.org/ontology/>
prefix uk:<http://data.open.ac.uk/ukresearchproject/ontology/>
prefix ox:<http://vocab.ox.ac.uk/projectfunding#>
  
SELECT DISTINCT  ?label ?text ?date ?description
WHERE { 
  # ?lexp event:time ?when.
  # ?when rdfs:label ?date.
  # ?lexp  dc:subject ?perf.
  # ?perf rdfs:label ?label.
  # ?lexp led:has_evidence_text ?text.
  FILTER(REGEX(?label, "brass band" , "i"))
}
"""
# set the query
sparql_wd.setQuery(query)
# set the returned format
sparql_wd.setReturnFormat(JSON)
# get the results
results_text = sparql_wd.query().convert()

# %%
# manipulate the result
for result in results_text["results"]["bindings"]:
    print(result["label"]["value"], "\n",result["text"]["value"], "\n")
# Out:
# performance of 'New Orleans Brass Band music'
#  Memories go back to the days of the loud jazz bands of the easy 'nineties [1890's], when we were just starting out with patch-up cornets and trombones, leaky valves on clarinets which were usually minus a key or two, and homemade bass fiddles, and warped guitars. We must have sounded just as lousy as the professional element, but by constant plugging night and day for days, months, and even years, some went on to fame and fortune (also ruin).
#
# performance of 'brass band'
#  The church-feast of its saint is of course for Anacapri, as for any self-respecting Italian town, the great day of the year���. As much of it as possible was squeezed all the morning, for St. Antony, into the piazzetta before the church, and as much more into that edifice as the robust odour mainly prevailing there allowed room for���. The shade outside was hot, and the sun was hot; but we waited as densely for him to come out, or rather to come ���on,��� as the pit at the opera waits for the great tenor. There were people from below and people from the mainland and people from Pomerania and a brass band from Naples���. The saint comes out at last, borne aloft in long procession and under a high canopy: a rejoicing, staring, smiling saint, openly delighted with the one happy hour in the year on which he may take his own walk. Frocked and tonsured, but not at all macerated, he holds in his hand a small wax puppet of an infant Jesus and shows him to all their friends, to whom he nods and bows: to whom, in the dazzle of the sun he literally seems to grin and wink, while his litter sways and his banners flap and every one gaily greets him. The ribbons and draperies flutter, and the white veils of the marching maidens, the music blares and the guns go off and the chants resound, and it is all as holy and merry and noisy as possible.... Singular and suggestive before everything else is the absence of any approach to our notion of the posture of respect, and this among people whose manners in general struck one as so good and, in particular, as so cultivated. The office of the saint��� of which the festa is but the annual reaffirmation���involves not the faintest attribute of remoteness or mystery
#
# performance of 'New Orleans Brass Band music'
#  When I was thirteen, I formed a band��� We had a homemade violin, bass viol, guitar, banjo--played on a chair for drums. We saved all the money we made, except for fifteen cents a piece for carfare, so we could buy good instruments later. We decided to go 'round crowds and hustle.
#
# We saved the money and I decided to give picnics with beer, salads--fifteen cents to come in and dance. We played the same numbers we are playing now, like "Pallet on the Floor", besides some waltzes. We used to go down to New Orleans weekends to hear the different bands that played in the parks. They play a tune once, that's all I want to hear so we could play it too. Take two and make one out of it if we couldn't get all of it.
#
# [Buddy] Bolden was one I heard and Edward Clem who had four or five pieces. He played something like Bolden--just passed through sometimes on an excursion. I used to go down to the railway station and sometimes I'd see him on the train passing through.
#
# performance of 'brass band military music'
#  I remember the Onward Brass Band had to play the marches for the Masonics or the Odd Fellows. They hired one band during the day--a big military band--that would play all the marches and that would introduce each dignitary of the organisation with military music. But the band was sitting. And between those introductions and the marching and the drilling, they would play some dance music, so they would swing.
#
# They played the shuffle beat on the snare drum and mostly two beats on the bass drums. At first, in the bands, the snare drums and the bass drums were played by different men like in the marching bands. But there was one particular guy in New Orleans who put the two drums together and played both himself, and that's where the foot pedal was invented.
#
# performance of 'brass band dance music'
#  I remember the Onward Brass Band had to play the marches for the Masonics or the Odd Fellows. They hired one band during the day--a big military band--that would play all the marches and that would introduce each dignitary of the organisation with military music. But the band was sitting. And between those introductions and the marching and the drilling, they would play some dance music, so they would swing.
#
# They played the shuffle beat on the snare drum and mostly two beats on the bass drums. At first, in the bands, the snare drums and the bass drums were played by different men like in the marching bands. But there was one particular guy in New Orleans who put the two drums together and played both himself, and that's where the foot pedal was invented.
#
# performance of 'New Orleans Brass Band music'
#  I remember the Onward Brass Band had to play the marches for the Masonics or the Odd Fellows. They hired one band during the day--a big military band--that would play all the marches and that would introduce each dignitary of the organisation with military music. But the band was sitting. And between those introductions and the marching and the drilling, they would play some dance music, so they would swing.
#
# They played the shuffle beat on the snare drum and mostly two beats on the bass drums. At first, in the bands, the snare drums and the bass drums were played by different men like in the marching bands. But there was one particular guy in New Orleans who put the two drums together and played both himself, and that's where the foot pedal was invented.

# %%
# SENTIMENT ANALYSIS:

# %%
for result in results_text["results"]["bindings"]:
    q =array([result["text"]["value"]])
    q=vect.transform(q)
    print(result["label"]["value"], "\n",model.predict(q), " ->",[result["text"]["value"]])
# Out:
# performance of 'New Orleans Brass Band music'
#  ['neg']  -> ["Memories go back to the days of the loud jazz bands of the easy 'nineties [1890's], when we were just starting out with patch-up cornets and trombones, leaky valves on clarinets which were usually minus a key or two, and homemade bass fiddles, and warped guitars. We must have sounded just as lousy as the professional element, but by constant plugging night and day for days, months, and even years, some went on to fame and fortune (also ruin). "]
# performance of 'brass band'

PREFIX dc: <http://purl.org/dc/terms/>
PREFIX edtf: <http://data.open.ac.uk/edtf/ontology/>
PREFIX edtfdata: <http://data.open.ac.uk/time/edtf/>
PREFIX event: <http://purl.org/NET/c4dm/event.owl#>
PREFIX led: <http://led.kmi.open.ac.uk/term/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX schema: <http://schema.org/>
prefix mo:<http://purl.org/ontology/mo/>
prefix db:<http://dbpedia.org/ontology/>
prefix uk:<http://data.open.ac.uk/ukresearchproject/ontology/>
prefix ox:<http://vocab.ox.ac.uk/projectfunding#>
  
SELECT DISTINCT  ?perf ?label ?author 
WHERE { 
  # ?perf mo:composer ?author.
  # ?perf rdfs:label ?label.
  FILTER(REGEX(?label, "brass band" , "i"))}
"""
# set the query
sparql_wd.setQuery(query)
# set the returned format
sparql_wd.setReturnFormat(JSON)
# get the results
results_author = sparql_wd.query().convert()

# %%
# manipulate the result
for result in results_author["results"]["bindings"]:
    print(result["label"]["value"],result["author"]["value"], "\n")
#not enough data for brass bads it seems
# Out:
# Walk��re for brass band http://dbpedia.org/resource/Richard_Wagner

# %% [markdown]
# # extra queries

# %% [markdown]
# ## sentiment analysis during war
#  - all positive

# %%
#retrieve texts for doing sentiment analysis
query_war = """
PREFIX dc: <http://purl.org/dc/terms/>
PREFIX edtf: <http://data.open.ac.uk/edtf/ontology/>
PREFIX edtfdata: <http://data.open.ac.uk/time/edtf/>
PREFIX event: <http://purl.org/NET/c4dm/event.owl#>
PREFIX led: <http://led.kmi.open.ac.uk/term/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX schema: <http://schema.org/>
prefix mo:<http://purl.org/ontology/mo/>
prefix db:<http://dbpedia.org/ontology/>
prefix uk:<http://data.open.ac.uk/ukresearchproject/ontology/>
prefix ox:<http://vocab.ox.ac.uk/projectfunding#>
  
SELECT DISTINCT  ?songlabel ?text ?date ?description ?when ?yoc
WHERE { 
  # ?lexp event:time [ rdfs:label ?when ; edtf:century edtfdata:Century.19 ; edtf:yearOfCentury/rdf:value ?yoc ].
  
  # ?lexp  dc:subject ?perf.
  # ?perf mo:performance_of ?song.
  # ?song rdfs:label ?songlabel.
  # ?lexp led:has_evidence_text ?text.
  FILTER ( ?yoc >= 39 && ?yoc <= 45 ) 
}
"""
# set the query
sparql_wd.setQuery(query_war)
# set the returned format
sparql_wd.setReturnFormat(JSON)
# get the results
results_war= sparql_wd.query().convert()

# %%
# easier way to obtain a dataframe
import pandas as pds
df_text = pds.DataFrame(results_war['results']['bindings'])
df_text.applymap(lambda x: x['value'])
# Out:
#                                             songlabel  \
# 0               Cello sonata n�� 1 in E minor, op. 38
# 1   Menuhin performs a concert for injured service...
# 2                                    Lincoln Portrait
# 3                                     La Marseillaise
# 4                                             Fa��ade
# ..                                                ...
# 62                          Weinen, Klagen variations
# 63                                     Piano Concerto
# 64                                     Symphony No. 5
# 65                                     Symphony No.16
# 66                                   Lincoln Portrait
#
#                                                  text             when yoc
# 0   One work, however, in the cellist���s repertor...             1945  45
# 1   For the troops stationed there life was not tr...             1945  45
# 2   Dear A\r\n\tJust a few words a propos of the L...             1943  43
# 3   The reopening of the Op��ra, the first chance ...             1945  45
# 4   My other extra mural activity at this time was...             1942  42
# ..                                                ...              ...  ..
# 62  This was the 1st recital in the rather restric...  7 October, 1939  39
# 63  This was a concert promoted by the S.C.R. and ...   13 April, 1940  40
# 64  This was a concert promoted by the S.C.R. and ...   13 April, 1940  40
# 65  This was a concert promoted by the S.C.R. and ...   13 April, 1940  40
# 66  After your description of Koussie���s Lincoln ...   10 April, 1943  43
#
# [67 rows x 4 columns]

# %%
df_sent_2 = pd.DataFrame(columns=['songlabel','year','sentiment'])
idx=0
for result in results_war["results"]["bindings"]:   
    v =array([result["text"]["value"]])
    v =vect.transform(v)
    sent=str(model.predict(v)).replace("[","").replace("]","")
    df_sent_2.loc[idx] = [result["songlabel"]["value"],result["yoc"]["value"],sent]
    idx+=1
df_sent_2
# Out:
#                                             songlabel year sentiment
# 0               Cello sonata n�� 1 in E minor, op. 38   45     'pos'
# 1   Menuhin performs a concert for injured service...   45     'pos'
# 2                                    Lincoln Portrait   43     'pos'
# 3                                     La Marseillaise   45     'pos'
# 4                                             Fa��ade   42     'pos'
# ..                                                ...  ...       ...
# 62                          Weinen, Klagen variations   39     'pos'
# 63                                     Piano Concerto   40     'pos'
# 64                                     Symphony No. 5   40     'pos'
# 65                                     Symphony No.16   40     'pos'
# 66                                   Lincoln Portrait   43     'pos'
#
# [67 rows x 3 columns]

# %%
list(df_sent_2["sentiment"]) #all positive

# %% [markdown]
# ## Retrieving places
# We have to decide if we want focus on the area of London/ England or represent a wider area. Cause we have also list. exp. outide England.

# %%
#retrieving the 10 most frequent leistening experiences' places on the database. we could apply the time filter if we want to use this
PREFIX dc: <http://purl.org/dc/terms/>
PREFIX edtf: <http://data.open.ac.uk/edtf/ontology/>
PREFIX edtfdata: <http://data.open.ac.uk/time/edtf/>
PREFIX event: <http://purl.org/NET/c4dm/event.owl#>
PREFIX led: <http://led.kmi.open.ac.uk/term/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX schema: <http://schema.org/>
prefix mo:<http://purl.org/ontology/mo/>
prefix db:<http://dbpedia.org/ontology/>
prefix uk:<http://data.open.ac.uk/ukresearchproject/ontology/>
prefix ox:<http://vocab.ox.ac.uk/projectfunding#>
prefix foaf:<http://xmlns.com/foaf/0.1/>

select  ?place (count(?lexp)as ?exp)
WHERE {
   # ?lexp event:time ?when;
    event:place ?place.
   # ?lexp  dc:subject ?perf.
   # ?perf rdfs:label ?perf_label; 
    mo:genre ?genre.

  # ?when rdfs:label ?date.
   
} group by ?place order by desc(?exp) limit 10

# %% [markdown]
# ## Focusing on live performances during the afterwar period

# %%
# retrieving live performances post 2w war  #delete?
query = """
PREFIX dc: <http://purl.org/dc/terms/>
PREFIX edtf: <http://data.open.ac.uk/edtf/ontology/>
PREFIX edtfdata: <http://data.open.ac.uk/time/edtf/>
PREFIX event: <http://purl.org/NET/c4dm/event.owl#>
PREFIX led: <http://led.kmi.open.ac.uk/term/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX schema: <http://schema.org/>
prefix mo:<http://purl.org/ontology/mo/>
prefix db:<http://dbpedia.org/ontology/>
prefix uk:<http://data.open.ac.uk/ukresearchproject/ontology/>
prefix ox:<http://vocab.ox.ac.uk/projectfunding#>
  
SELECT DISTINCT  ?perf ?label ?genre_label ?performer_label
WHERE { 
  # ?lexp led:has_medium led:Medium.Live.
  # ?lexp event:time [ rdfs:label ?when ; edtf:century edtfdata:Century.19 ; edtf:yearOfCentury/rdf:value ?yoc ].
  # ?lexp  dc:subject ?perf.
  # ?perf rdfs:label ?label;
    mo:genre ?genre;
    	mo:performer ?performer.
  # ?genre rdfs:label ?genre_label.
  # ?performer rdfs:label ?performer_label.
   FILTER ( ?yoc >=46 && ?yoc <= 52 ) 
  }
"""
# set the query
sparql_wd.setQuery(query)
# set the returned format
sparql_wd.setReturnFormat(JSON)
# get the results
results= sparql_wd.query().convert()
# manipulate the result
for result in results["results"]["bindings"]:
    print(result["label"]["value"]," GENRE: ", result["genre_label"]["value"], " PERFORMER: ", result["performer_label"]["value"])

# since the research is focused on non 'elite' music,
# we could search for performances excluding the ones of Classical Music/Opera/Simphony/Chamber music
#  (I think these genres could be defined 'elite' music since they were listened by the most rich/educated people -> 'elite' )
# we could focus on Blues music/rock/country for example
# Out:
# performance of 'unspecified orchestral music'  GENRE:  Classical music  PERFORMER:  Richard Strauss
# performance of 'unspecified orchestral music'  GENRE:  Classical music  PERFORMER:  Richard Strauss
# performance of 'unspecified orchestral music'  GENRE:  Classical music  PERFORMER:  Richard Strauss
# performance of 'unspecified orchestral music'  GENRE:  Classical music  PERFORMER:  Richard Strauss
# performance of 'unspecified orchestral music'  GENRE:  Classical music  PERFORMER:  Richard Strauss (conductor)
# performance of 'unspecified orchestral music'  GENRE:  Classical music  PERFORMER:  Richard Strauss (conductor)
# performance of 'unspecified orchestral music'  GENRE:  Classical music  PERFORMER:  Royal Philharmonic Orchestra
# performance of 'unspecified orchestral music'  GENRE:  Classical music  PERFORMER:  Royal Philharmonic Orchestra
# performance of 'unspecified orchestral music'  GENRE:  Classical music  PERFORMER:  Royal Philharmonic Orchestra
# performance of 'unspecified orchestral music'  GENRE:  Classical music  PERFORMER:  Royal Philharmonic Orchestra
# performance of 'Stravinsky's Third Symphony'  GENRE:  Symphony  PERFORMER:  Ernest Ansermet
# performance of 'Stravinsky's Third Symphony'  GENRE:  Symphony  PERFORMER:  Ernest Ansermet
# performance of 'Stravinsky's Third Symphony'  GENRE:  20th-century classical music  PERFORMER:  Ernest Ansermet
# performance of ''Manon''  GENRE:  Opera  PERFORMER:  Heddle Nash
# performance of ''Manon''  GENRE:  Opera  PERFORMER:  Heddle Nash
# performance of ''Manon''  GENRE:  Operatic  PERFORMER:  Heddle Nash
# performance of ''Manon''  GENRE:  Solo  PERFORMER:  Heddle Nash
# performance of ''Manon''  GENRE:  Solo (music)  PERFORMER:  Heddle Nash
# performance of ''Manon''  GENRE:  Opera  PERFORMER:  Covent Garden Opera Company
# performance of ''Manon''  GENRE:  Opera  PERFORMER:  Covent Garden Opera Company
# performance of ''